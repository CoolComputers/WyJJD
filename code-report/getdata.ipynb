# %%
from ipywidgets import widgets
import csv
import numpy as np
import pandas as pd

data_folder = '../new-data/'
dci_data_folder = data_folder+'DCI/all-combined/'
dfs_afcars_data_file = data_folder+'DFS/DFS_12-16-AFCARS-CLEAN.csv'
dfs_county_data_file = data_folder+'DFS/DFS_12-16-Placements-ByCounty-CLEAN.csv'
dfs_plc_data_file = data_folder+'DFS/DFS_12-16-Placements-ByPLC-CLEAN.csv'
school_discipline_data_file = data_folder+'school-discipline/SchoolDiscipline_2007-16_Combined-CSV.csv'

# dfs_afcars_data = np.genfromtxt(dfs_afcars_data_file, delimiter=",", skip_header=0)
# dfs_county_data = np.genfromtxt(dfs_county_data_file, delimiter=",", skip_header=0)
# dfs_plc_data = np.genfromtxt(dfs_plc_data_file, delimiter=",", skip_header=0)
# school_discipline_data = np.genfromtxt(school_discipline_data_file, delimiter=";", skip_header=1)

dfs_afcars_data = pd.read_csv(dfs_afcars_data_file,sep=',',header='infer',index_col=0)
dfs_county_data = pd.read_csv(dfs_county_data_file,sep=',',header='infer',index_col=0)
dfs_plc_data = pd.read_csv(dfs_plc_data_file,sep=',',header='infer',index_col=0)
school_discipline_data = pd.read_csv(school_discipline_data_file,sep=',',header='infer',index_col=0)

print(dfs_afcars_data)
print(dfs_county_data)
print(dfs_plc_data)
print(school_discipline_data)
# Out:
#             YEAR  CHINS  DE
# COUNTY
# Albany      2012      0  10
# Albany      2013      0   9
# Albany      2014      1  14
# Albany      2015      2   7
# Albany      2016      0   3
# Big Horn    2012      1   6
# Big Horn    2013      1   7
# Big Horn    2014      0   3
# Big Horn    2015      2   5
# Big Horn    2016      0   3
# Campbell    2012     20  51
# Campbell    2013      9  32
# Campbell    2014      9  30
# Campbell    2015      9  28
# Campbell    2016     15  21
# Carbon      2012      0  12
# Carbon      2013      0   5
# Carbon      2014      0   5
# Carbon      2015      0   9
# Carbon      2016      4   8
# Converse    2012      1  15
# Converse    2013      1  18
# Converse    2014      2  16
# Converse    2015      1   6
# Converse    2016      1  13
# Crook       2012      0   2
# Crook       2013      0   1
# Crook       2014      1   2
# Crook       2015      0   4
# Crook       2016      0   1
# ...          ...    ...  ..
# Sublette    2012      1  12
# Sublette    2013      6   4
# Sublette    2014      2   4
# Sublette    2015      1   3
# Sublette    2016      1   1
# Sweetwater  2012     18  63
# Sweetwater  2013     21  66
# Sweetwater  2014     22  69
# Sweetwater  2015     26  42
# Sweetwater  2016     48  62
# Teton       2012      6  12
# Teton       2013      1   6
# Teton       2014      1   8
# Teton       2015      1   4
# Teton       2016      4   6
# Uinta       2012      0   5
# Uinta       2013      1   4
# Uinta       2014      0   1
# Uinta       2015      1   8
# Uinta       2016      2   8
# Washakie    2012      0   1
# Washakie    2013      0   2
# Washakie    2014      0   2
# Washakie    2015      0   8
# Washakie    2016      0   3
# Weston      2012      0   4
# Weston      2013      1   2
# Weston      2014      0   2
# Weston      2015      0   6
# Weston      2016      0   5
#
# [115 rows x 3 columns]
#             YEAR  CHINS   DE
# COUNTY
# Albany      2012    0.0   34
# Albany      2013    0.0   37
# Albany      2014    1.0   45
# Albany      2015    2.0   29
# Albany      2016    0.0   15
# Big Horn    2012    1.0   13
# Big Horn    2013    1.0   20
# Big Horn    2014    2.0   15
# Big Horn    2015    5.0    6
# Big Horn    2016    4.0    9
# Campbell    2012   29.0   99
# Campbell    2013   17.0   61
# Campbell    2014   19.0   82
# Campbell    2015   18.0   62
# Campbell    2016   28.0   50
# Carbon      2012    0.0   31
# Carbon      2013    0.0   17
# Carbon      2014    0.0   21
# Carbon      2015    3.0   31
# Carbon      2016    7.0   36
# Converse    2012    6.0   38
# Converse    2013    5.0   51
# Converse    2014    5.0   47
# Converse    2015    2.0   25
# Converse    2016    4.0   38
# Crook       2012    0.0    4
# Crook       2013    1.0    2
# Crook       2014    2.0    8
# Crook       2015    0.0    9
# Crook       2016    0.0    7
# ...          ...    ...  ...
# Sublette    2012    4.0   32
# Sublette    2013    9.0   13
# Sublette    2014   15.0   11
# Sublette    2015    3.0    9
# Sublette    2016    2.0    2
# Sweetwater  2012   38.0  180
# Sweetwater  2013   35.0  186
# Sweetwater  2014   41.0  176
# Sweetwater  2015   37.0  124
# Sweetwater  2016   68.0  134
# Teton       2012    7.0   25
# Teton       2013    5.0   19
# Teton       2014    1.0   21
# Teton       2015    2.0   14
# Teton       2016   12.0   14
# Uinta       2012    0.0   15
# Uinta       2013    2.0   14
# Uinta       2014    0.0    4
# Uinta       2015    1.0   19
# Uinta       2016    4.0   18
# Washakie    2012    NaN    1
# Washakie    2013    NaN    8
# Washakie    2014    NaN    6
# Washakie    2015    NaN   17
# Washakie    2016    NaN   19
# Weston      2012    0.0    8
# Weston      2013    1.0    2
# Weston      2014    0.0    8
# Weston      2015    0.0   19
# Weston      2016    0.0   12
#
# [115 rows x 3 columns]
#                              YEAR  CHINS   DE
# PLC Type
# Boys School                  2012      0  112
# Boys School                  2013      0  111
# Boys School                  2014      0  103
# Boys School                  2015      0  105
# Boys School                  2016      0  106
# Crisis Center                2012     22  200
# Crisis Center                2013     27  240
# Crisis Center                2014     37  219
# Crisis Center                2015     37  213
# Crisis Center                2016     42  176
# Detention                    2012     22  200
# Detention                    2013     27  240
# Detention                    2014     37  219
# Detention                    2015     37  213
# Detention                    2016     42  176
# FC Non-Relative              2012     16   24
# FC Non-Relative              2013     10   29
# FC Non-Relative              2014      9   24
# FC Non-Relative              2015     11   22
# FC Non-Relative              2016     24   13
# FC Relative                  2012      1    6
# FC Relative                  2013      1   14
# FC Relative                  2014      6   11
# FC Relative                  2015      5    2
# FC Relative                  2016      4    8
# Girls School                 2012      0   47
# Girls School                 2013      0   43
# Girls School                 2014      0   35
# Girls School                 2015      0   40
# Girls School                 2016      0   51
# ...                           ...    ...  ...
# Runaway                      2012      4    8
# Runaway                      2013      0    9
# Runaway                      2014      3   14
# Runaway                      2015      2    6
# Runaway                      2016      8    4
# Specialised FC Non-Relative  2012      0    0
# Specialised FC Non-Relative  2013      0    0
# Specialised FC Non-Relative  2014      0    1
# Specialised FC Non-Relative  2015      0    0
# Specialised FC Non-Relative  2016      0    0
# State Hospital               2012      0    2
# State Hospital               2013      0    0
# State Hospital               2014      0    1
# State Hospital               2015      0    0
# State Hospital               2016      0    1
# Therapy FC Non-Relative      2012      0    6
# Therapy FC Non-Relative      2013      0    3
# Therapy FC Non-Relative      2014      0    2
# Therapy FC Non-Relative      2015      0    1
# Therapy FC Non-Relative      2016      0    1
# Therapy FC Relative          2012      0    0
# Therapy FC Relative          2013      0    1
# Therapy FC Relative          2014      0    0
# Therapy FC Relative          2015      0    0
# Therapy FC Relative          2016      0    0
# Trial Home Placement         2012      5   36
# Trial Home Placement         2013     14   40
# Trial Home Placement         2014     16   42
# Trial Home Placement         2015      7   34
# Trial Home Placement         2016     13   37
#
# [100 rows x 3 columns]
#               DISTRICT_NAME  Beginning Year  End Year  \
# DISTRICT_ID
# 101000            Albany #1            2007      2008
# 201000          Big Horn #1            2007      2008
# 202000          Big Horn #2            2007      2008
# 203000          Big Horn #3            2007      2008
# 204000          Big Horn #4            2007      2008
# 301000          Campbell #1            2007      2008
# 401000            Carbon #1            2007      2008
# 402000            Carbon #2            2007      2008
# 501000          Converse #1            2007      2008
# 502000          Converse #2            2007      2008
# 601000             Crook #1            2007      2008
# 701000           Fremont #1            2007      2008
# 702000           Fremont #2            2007      2008
# 706000           Fremont #6            2007      2008
# 714000          Fremont #14            2007      2008
# 721000          Fremont #21            2007      2008
# 724000          Fremont #24            2007      2008
# 725000          Fremont #25            2007      2008
# 738000          Fremont #38            2007      2008
# 801000            Goshen #1            2007      2008
# 901000       Hot Springs #1            2007      2008
# 1001000          Johnson #1            2007      2008
# 1101000          Laramie #1            2007      2008
# 1102000          Laramie #2            2007      2008
# 1201000          Lincoln #1            2007      2008
# 1202000          Lincoln #2            2007      2008
# 1301000          Natrona #1            2007      2008
# 1401000         Niobrara #1            2007      2008
# 1501000             Park #1            2007      2008
# 1506000             Park #6            2007      2008
# ...                     ...             ...       ...
# 714000          Fremont #14            2015      2016
# 721000          Fremont #21            2015      2016
# 724000          Fremont #24            2015      2016
# 725000          Fremont #25            2015      2016
# 738000          Fremont #38            2015      2016
# 801000            Goshen #1            2015      2016
# 1001000          Johnson #1            2015      2016
# 1101000          Laramie #1            2015      2016
# 1102000          Laramie #2            2015      2016
# 1201000          Lincoln #1            2015      2016
# 1202000          Lincoln #2            2015      2016
# 1301000          Natrona #1            2015      2016
# 1401000         Niobrara #1            2015      2016
# 1501000             Park #1            2015      2016
# 1506000             Park #6            2015      2016
# 1516000            Park #16            2015      2016
# 1601000           Platte #1            2015      2016
# 1602000           Platte #2            2015      2016
# 1701000         Sheridan #1            2015      2016
# 1702000         Sheridan #2            2015      2016
# 1801000         Sublette #1            2015      2016
# 1809000         Sublette #9            2015      2016
# 1901000       Sweetwater #1            2015      2016
# 1902000       Sweetwater #2            2015      2016
# 2001000            Teton #1            2015      2016
# 2101000            Uinta #1            2015      2016
# 2104000            Uinta #4            2015      2016
# 2201000         Washakie #1            2015      2016
# 2202000         Washakie #2            2015      2016
# 2307000           Weston #7            2015      2016
#
#              Expulsion - Services not provided  Expulsion - Services provided  \
# DISTRICT_ID
# 101000                                     NaN                            NaN
# 201000                                     NaN                            NaN
# 202000                                     NaN                            NaN
# 203000                                     NaN                            NaN
# 204000                                     NaN                            NaN
# 301000                                     1.0                            NaN
# 401000                                     NaN                            NaN
# 402000                                     NaN                            NaN
# 501000                                     NaN                            NaN
# 502000                                     NaN                            NaN
# 601000                                     NaN                            NaN
# 701000                                     NaN                            NaN
# 702000                                     NaN                            NaN
# 706000                                     NaN                            NaN
# 714000                                     NaN                            NaN
# 721000                                     NaN                            NaN
# 724000                                     NaN                            NaN
# 725000                                     NaN                            NaN
# 738000                                     NaN                            NaN
# 801000                                     NaN                            NaN
# 901000                                     NaN                            1.0
# 1001000                                    NaN                            NaN
# 1101000                                   14.0                            3.0
# 1102000                                    NaN                            NaN
# 1201000                                    NaN                            NaN
# 1202000                                    NaN                            NaN
# 1301000                                    NaN                            NaN
# 1401000                                    NaN                            NaN
# 1501000                                    NaN                            1.0
# 1506000                                    NaN                            NaN
# ...                                        ...                            ...
# 714000                                     NaN                            NaN
# 721000                                     NaN                            NaN
# 724000                                     NaN                            NaN
# 725000                                     NaN                            3.0
# 738000                                     NaN                            1.0
# 801000                                     NaN                            NaN
# 1001000                                    NaN                            NaN
# 1101000                                    2.0                            6.0
# 1102000                                    NaN                            NaN
# 1201000                                    NaN                            NaN
# 1202000                                    NaN                            1.0
# 1301000                                    5.0                            7.0
# 1401000                                    NaN                            NaN
# 1501000                                    4.0                            NaN
# 1506000                                    NaN                            NaN
# 1516000                                    NaN                            NaN
# 1601000                                    NaN                            NaN
# 1602000                                    NaN                            NaN
# 1701000                                    1.0                            NaN
# 1702000                                    NaN                            NaN
# 1801000                                    1.0                            NaN
# 1809000                                    NaN                            NaN
# 1901000                                    1.0                            NaN
# 1902000                                    NaN                            1.0
# 2001000                                    NaN                            NaN
# 2101000                                    NaN                            1.0
# 2104000                                    NaN                            NaN
# 2201000                                    NaN                            NaN
# 2202000                                    NaN                            NaN
# 2307000                                    NaN                            NaN
#
#              In school suspension  Out of school suspension
# DISTRICT_ID
# 101000                       35.0                     154.0
# 201000                       22.0                      23.0
# 202000                        2.0                      45.0
# 203000                       74.0                      39.0
# 204000                        7.0                      16.0
# 301000                      259.0                      55.0
# 401000                      429.0                     282.0
# 402000                       29.0                      20.0
# 501000                       41.0                      45.0
# 502000                       22.0                      49.0
# 601000                       30.0                      13.0
# 701000                       20.0                      86.0
# 702000                       34.0                       6.0
# 706000                       14.0                      14.0
# 714000                       96.0                      25.0
# 721000                        NaN                      40.0
# 724000                        4.0                      19.0
# 725000                        NaN                      90.0
# 738000                       13.0                      57.0
# 801000                        NaN                      63.0
# 901000                        8.0                      35.0
# 1001000                       5.0                      20.0
# 1101000                      70.0                     369.0
# 1102000                      84.0                      64.0
# 1201000                      27.0                      23.0
# 1202000                       NaN                      22.0
# 1301000                    2125.0                     448.0
# 1401000                       NaN                       NaN
# 1501000                     256.0                      85.0
# 1506000                      11.0                      41.0
# ...                           ...                       ...
# 714000                        1.0                      40.0
# 721000                        NaN                      69.0
# 724000                        7.0                      11.0
# 725000                      465.0                     410.0
# 738000                        1.0                      57.0
# 801000                       84.0                     151.0
# 1001000                      21.0                       4.0
# 1101000                       NaN                      68.0
# 1102000                      38.0                       9.0
# 1201000                       NaN                       1.0
# 1202000                     144.0                       1.0
# 1301000                    1929.0                     948.0
# 1401000                       4.0                       4.0
# 1501000                     201.0                      99.0
# 1506000                       4.0                      29.0
# 1516000                       NaN                       5.0
# 1601000                      69.0                      29.0
# 1602000                       7.0                      27.0
# 1701000                      42.0                      18.0
# 1702000                     619.0                      69.0
# 1801000                      34.0                      34.0
# 1809000                      45.0                      21.0
# 1901000                     404.0                     221.0
# 1902000                     426.0                     209.0
# 2001000                      86.0                      44.0
# 2101000                     761.0                      86.0
# 2104000                      36.0                      18.0
# 2201000                       NaN                      18.0
# 2202000                       2.0                       1.0
# 2307000                      23.0                       3.0
#
# [420 rows x 7 columns]

# %%
import os, sys
import subprocess
#dir_path = os.path.dirname(os.path.realpath(__file__))
dir_path = os.getcwd()
print('currentpath='+str(dir_path))

#dci_year_folders = next(os.walk(dci_data_folder))[0]#current folder
dci_year_folders = next(os.walk(dci_data_folder))[1]#folders in this dir
#studentRepoFolders = next(os.walk(dci_data_folder))[2]#files in this dir
list.sort(dci_year_folders)

print("found "+str(len(dci_year_folders))+" repos")
print(str(dci_year_folders))

dci_data_obj = []
# Out:
# currentpath=/home/scrypy/work/wclc/New-Report/code-report
# found 6 repos
# ['2012', '2013', '2014', '2015', '2016', '2017']

# %%
def getAllData():
    for year in dci_year_folders:#process each year folder 
        dci_data_obj.append(year)
        current_path = dci_data_folder+year
        year_files = next(os.walk(current_path))[2]
        #print(year_files)
        for f in year_files:#process each file for this year
            file_path = current_path+'/'+f
            try:
                tmpFile = np.genfromtxt(file_path, delimiter=",", skip_header=0)
                #print('loaded file: '+file_path)
            except Exception as e:
                print('cant load file: '+file_path)
                print('['+str(e)+']')
                print('*****************************************************************************************')
                print('*****************************************************************************************')
            #print(tmpFile)
        #for f in next(os.walk(dci_data_folder+'/'+year)):
#getAllData()

# %%
def getOverview():#DONE
    gather_overview_frames = []    
    current_path = dci_data_folder+'overview/'
    print(current_path)
    year_files = next(os.walk(current_path))[2]
    for f in year_files:#process each file for this year
        file_path = current_path+'/'+f
        year = f.split('-')[0]
        try:
            #gather_overview_frames[year] = np.genfromtxt(file_path, delimiter=",", skip_header=1)
            df = pd.read_csv(file_path,sep=',',header='infer',index_col=0)
            df.assign(Year=year)
            gather_overview_frames.append(df)
        except Exception as e:
            print('cant load file: '+file_path)
            print('['+str(e)+']')
            print('*****************************************************************************************')
            
                    
    return pd.concat(gather_overview_frames)
#getOverview()
