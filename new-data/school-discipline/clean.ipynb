# %%
import pandas as pd 
import csv 
# first save each year into its own csv
# add columns for begin/end years
# this is to fix a problem where some columns where not in the 
# same order as other files

years = ['07','08','09','10','11','12','13','14','15','16','17']

# print(years[:len(years)-1])
# for begin,end in zip(years[:len(years)-1],years[1:]):
#     print(begin,end)
    
totals = []
for begin,end in zip(years[:len(years)-1],years[1:]):
    print('./{}-{}_Data.csv'.format(begin,end))
    fl = open('./{}-{}_Data.csv'.format(begin,end),'r')
    cols = fl.readline().strip('\ufeff').strip('\n').split(',')
    print(cols)
    for line in fl:
        line = line.strip()
        obj = {}
        for col,val in zip(cols,line.split(',')):
            if val == '':
                obj[col]='0'
            else:
                obj[col] = val
        totals.append(obj)
        
        
    fl.close()
print(totals[0])
print(len(totals))

txt_cols = ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided',
            'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
outf = open("combined_discipline{}-{}.csv".format(years[0],years[-1]), "w")
outf.write(','.join(txt_cols))
outf.write('\n')
for obj in totals:
    #for col in txt_cols:
    outf.write("{},{},{},{},{},{},{},{},{}\n".format(
        obj[txt_cols[0]],
        obj[txt_cols[1]],
        obj[txt_cols[2]],
        obj[txt_cols[3]],
        obj[txt_cols[4]],
        obj[txt_cols[5]],
        obj[txt_cols[6]],
        obj[txt_cols[7]],
        obj[txt_cols[8]],
    ))
    print("{},{},{},{},{},{},{},{},{}".format(
        obj[txt_cols[0]],
        obj[txt_cols[1]],
        obj[txt_cols[2]],
        obj[txt_cols[3]],
        obj[txt_cols[4]],
        obj[txt_cols[5]],
        obj[txt_cols[6]],
        obj[txt_cols[7]],
        obj[txt_cols[8]],
    ))
outf.close()
            
            
# w = csv.writer(open("combined_discipline{}-{}.csv".format(years[0],years[-1], "w"))
# for key, val in dict.items():
#     w.writerow([key, val])
               
#     df = pd.read_csv('./{}-{}_Data.csv'.format(begin,end),header='infer',sep=',')
#     print(df.head())
# Out:
# ./07-08_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./08-09_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./09-10_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./10-11_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./11-12_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./12-13_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./13-14_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./14-15_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'In school suspension', 'Out of school suspension', 'Expulsion - Services provided', 'Total']
# ./15-16_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# ./16-17_Data.csv
# ['begin', 'end', 'DISTRICT_ID', 'DISTRICT_NAME', 'Expulsion - Services not provided', 'Expulsion - Services provided', 'In school suspension', 'Out of school suspension', 'Total']
# {'begin': '2007', 'end': '2008', 'DISTRICT_ID': '101000', 'DISTRICT_NAME': 'Albany #1', 'Expulsion - Services not provided': '0', 'Expulsion - Services provided': '0', 'In school suspension': '35', 'Out of school suspension': '154', 'Total': '194'}
# 469
# 2007,2008,101000,Albany #1,0,0,35,154,194
# 2007,2008,201000,Big Horn #1,0,0,22,23,52
# 2007,2008,202000,Big Horn #2,0,0,2,45,47
# 2007,2008,203000,Big Horn #3,0,0,74,39,113
# 2007,2008,204000,Big Horn #4,0,0,7,16,23
# 2007,2008,301000,Campbell #1,1,0,259,55,317
# 2007,2008,401000,Carbon #1,0,0,429,282,712
# 2007,2008,402000,Carbon #2,0,0,29,20,51
# 2007,2008,501000,Converse #1,0,0,41,45,103
# 2007,2008,502000,Converse #2,0,0,22,49,71
# 2007,2008,601000,Crook #1,0,0,30,13,43
# 2007,2008,701000,Fremont #1,0,0,20,86,108
# 2007,2008,702000,Fremont #2,0,0,34,6,46
# 2007,2008,706000,Fremont #6,0,0,14,14,30
# 2007,2008,714000,Fremont #14,0,0,96,25,121
# 2007,2008,721000,Fremont #21,0,0,0,40,132
# 2007,2008,724000,Fremont #24,0,0,4,19,23
# 2007,2008,725000,Fremont #25,0,0,0,90,90
# 2007,2008,738000,Fremont #38,0,0,13,57,191
# 2007,2008,801000,Goshen #1,0,0,0,63,63
# 2007,2008,901000,Hot Springs #1,0,1,8,35,53
# 2007,2008,1001000,Johnson #1,0,0,5,20,25
# 2007,2008,1101000,Laramie #1,14,3,70,369,630
# 2007,2008,1102000,Laramie #2,0,0,84,64,148
# 2007,2008,1201000,Lincoln #1,0,0,27,23,53
# 2007,2008,1202000,Lincoln #2,0,0,0,22,22
# 2007,2008,1301000,Natrona #1,0,0,2125,448,3497
# 2007,2008,1401000,Niobrara #1,0,0,0,0,0
# 2007,2008,1501000,Park #1,0,1,256,85,351
# 2007,2008,1506000,Park #6,0,0,11,41,52
# 2007,2008,1516000,Park #16,0,0,17,6,28
# 2007,2008,1601000,Platte #1,1,0,35,48,302
# 2007,2008,1602000,Platte #2,0,0,0,7,7
# 2007,2008,1701000,Sheridan #1,0,0,2,7,9
# 2007,2008,1702000,Sheridan #2,0,0,0,85,779
# 2007,2008,1703000,Sheridan #3,0,0,0,0,0
# 2007,2008,1801000,Sublette #1,0,0,26,34,60
# 2007,2008,1809000,Sublette #9,0,0,0,33,33
# 2007,2008,1901000,Sweetwater #1,1,0,623,244,1829
# 2007,2008,1902000,Sweetwater #2,0,0,235,175,421
# 2007,2008,2001000,Teton #1,0,0,28,57,88
# 2007,2008,2101000,Uinta #1,0,0,862,346,1208
# 2007,2008,2104000,Uinta #4,1,0,17,25,43
# 2007,2008,2106000,Uinta #6,0,0,34,17,52
# 2007,2008,2201000,Washakie #1,0,0,9,52,61
# 2007,2008,2202000,Washakie #2,0,0,3,1,4
# 2007,2008,2301000,Weston #1,0,0,1,0,1
# 2007,2008,2307000,Weston #7,0,0,26,6,32
# 2008,2009,101000,Albany #1,0,0,45,114,162
# 2008,2009,201000,Big Horn #1,0,0,15,14,30
# 2008,2009,202000,Big Horn #2,0,0,0,46,46
# 2008,2009,203000,Big Horn #3,1,0,82,28,111
# 2008,2009,204000,Big Horn #4,0,0,23,16,59
# 2008,2009,301000,Campbell #1,5,3,128,38,232
# 2008,2009,401000,Carbon #1,1,0,264,323,588
# 2008,2009,402000,Carbon #2,0,1,19,13,33
# 2008,2009,501000,Converse #1,0,0,2,28,48
# 2008,2009,502000,Converse #2,0,0,2,33,35
# 2008,2009,601000,Crook #1,0,0,10,5,15
# 2008,2009,701000,Fremont #1,0,0,66,67,212
# 2008,2009,702000,Fremont #2,0,0,31,6,37
# 2008,2009,706000,Fremont #6,0,0,0,40,41
# 2008,2009,714000,Fremont #14,0,0,104,68,172
# 2008,2009,721000,Fremont #21,0,0,0,30,30
# 2008,2009,724000,Fremont #24,0,0,12,2,25
# 2008,2009,725000,Fremont #25,0,0,22,293,316
# 2008,2009,738000,Fremont #38,0,0,2,21,23
# 2008,2009,801000,Goshen #1,0,0,3,65,68
# 2008,2009,901000,Hot Springs #1,4,0,6,37,50
# 2008,2009,1001000,Johnson #1,0,0,8,8,25
# 2008,2009,1101000,Laramie #1,35,3,652,696,1509
# 2008,2009,1102000,Laramie #2,0,0,46,30,83
# 2008,2009,1201000,Lincoln #1,0,0,15,9,24
# 2008,2009,1202000,Lincoln #2,0,0,1,26,28
# 2008,2009,1301000,Natrona #1,0,0,1899,618,3405
# 2008,2009,1401000,Niobrara #1,0,0,6,1,8
# 2008,2009,1501000,Park #1,0,0,169,89,269
# 2008,2009,1506000,Park #6,1,1,7,19,28
# 2008,2009,1516000,Park #16,0,0,15,0,15
# 2008,2009,1601000,Platte #1,1,0,17,26,87
# 2008,2009,1602000,Platte #2,0,0,0,7,7
# 2008,2009,1701000,Sheridan #1,0,0,0,7,7
# 2008,2009,1702000,Sheridan #2,6,0,22,54,635
# 2008,2009,1703000,Sheridan #3,0,0,0,4,4
# 2008,2009,1801000,Sublette #1,1,0,7,49,57
# 2008,2009,1809000,Sublette #9,0,0,67,47,125
# 2008,2009,1901000,Sweetwater #1,0,0,875,355,1230
# 2008,2009,1902000,Sweetwater #2,0,0,326,195,523
# 2008,2009,2001000,Teton #1,0,2,23,20,50
# 2008,2009,2101000,Uinta #1,0,0,3038,442,3480
# 2008,2009,2104000,Uinta #4,0,0,6,27,33
# 2008,2009,2106000,Uinta #6,0,0,8,23,31
# 2008,2009,2201000,Washakie #1,0,0,6,29,41
# 2008,2009,2202000,Washakie #2,0,0,0,0,0
# 2008,2009,2301000,Weston #1,0,0,0,1,1
# 2008,2009,2307000,Weston #7,0,0,1,0,1
# 2009,2010,101000,Albany #1,0,0,0,124,125
# 2009,2010,201000,Big Horn #1,0,0,6,6,13
# 2009,2010,202000,Big Horn #2,1,0,11,6,18
# 2009,2010,203000,Big Horn #3,0,0,89,26,115
# 2009,2010,204000,Big Horn #4,0,0,21,10,46
# 2009,2010,301000,Campbell #1,5,0,352,60,516
# 2009,2010,401000,Carbon #1,0,0,197,346,543
# 2009,2010,402000,Carbon #2,0,0,9,7,16
# 2009,2010,501000,Converse #1,0,0,135,28,218
# 2009,2010,502000,Converse #2,0,0,3,21,24
# 2009,2010,601000,Crook #1,0,0,1,2,3
# 2009,2010,701000,Fremont #1,2,0,371,102,500
# 2009,2010,702000,Fremont #2,0,0,13,8,21
# 2009,2010,706000,Fremont #6,0,0,0,33,33
# 2009,2010,714000,Fremont #14,0,0,47,27,74
# 2009,2010,721000,Fremont #21,0,0,2,58,267
# 2009,2010,724000,Fremont #24,0,0,24,3,27
# 2009,2010,725000,Fremont #25,0,14,29,360,404
# 2009,2010,738000,Fremont #38,0,0,0,66,66
# 2009,2010,801000,Goshen #1,0,0,8,78,86
# 2009,2010,901000,Hot Springs #1,0,0,30,40,71
# 2009,2010,1001000,Johnson #1,0,0,40,30,70
# 2009,2010,1101000,Laramie #1,21,6,0,25,52
# 2009,2010,1102000,Laramie #2,0,0,38,28,66
# 2009,2010,1201000,Lincoln #1,0,0,26,4,31
# 2009,2010,1202000,Lincoln #2,2,6,10,53,103
# 2009,2010,1301000,Natrona #1,0,0,1484,654,2737
# 2009,2010,1401000,Niobrara #1,1,0,7,2,12
# 2009,2010,1501000,Park #1,1,0,127,63,198
# 2009,2010,1506000,Park #6,0,0,33,15,49
# 2009,2010,1516000,Park #16,0,0,17,9,28
# 2009,2010,1601000,Platte #1,0,0,26,36,116
# 2009,2010,1602000,Platte #2,0,0,0,11,11
# 2009,2010,1701000,Sheridan #1,0,0,0,5,10
# 2009,2010,1702000,Sheridan #2,2,0,21,56,580
# 2009,2010,1703000,Sheridan #3,0,0,14,4,18
# 2009,2010,1801000,Sublette #1,1,1,15,46,63
# 2009,2010,1809000,Sublette #9,0,0,46,43,89
# 2009,2010,1901000,Sweetwater #1,0,0,781,342,2288
# 2009,2010,1902000,Sweetwater #2,0,0,323,136,492
# 2009,2010,2001000,Teton #1,0,1,245,48,296
# 2009,2010,2101000,Uinta #1,0,0,733,354,1671
# 2009,2010,2104000,Uinta #4,0,0,3,35,40
# 2009,2010,2106000,Uinta #6,0,0,5,18,25
# 2009,2010,2201000,Washakie #1,0,0,25,27,52
# 2009,2010,2202000,Washakie #2,0,0,0,0,0
# 2009,2010,2301000,Weston #1,0,0,0,6,6
# 2009,2010,2307000,Weston #7,0,0,22,0,22
# 2010,2011,101000,Albany #1,0,0,0,96,96
# 2010,2011,201000,Big Horn #1,0,0,0,0,0
# 2010,2011,202000,Big Horn #2,0,0,0,0,0
# 2010,2011,203000,Big Horn #3,0,0,0,0,0
# 2010,2011,204000,Big Horn #4,0,0,0,0,0
# 2010,2011,301000,Campbell #1,0,0,178,59,237
# 2010,2011,401000,Carbon #1,0,0,0,0,0
# 2010,2011,402000,Carbon #2,0,0,1,8,9
# 2010,2011,501000,Converse #1,0,0,98,7,128
# 2010,2011,502000,Converse #2,0,0,0,0,0
# 2010,2011,601000,Crook #1,0,0,26,8,34
# 2010,2011,701000,Fremont #1,0,0,313,221,535
# 2010,2011,702000,Fremont #2,0,0,0,0,0
# 2010,2011,706000,Fremont #6,0,0,0,0,0
# 2010,2011,714000,Fremont #14,0,0,0,0,9
# 2010,2011,721000,Fremont #21,0,0,0,0,0
# 2010,2011,724000,Fremont #24,0,0,51,11,93
# 2010,2011,725000,Fremont #25,0,11,489,395,4256
# 2010,2011,738000,Fremont #38,0,0,0,0,0
# 2010,2011,801000,Goshen #1,0,0,0,0,0
# 2010,2011,901000,Hot Springs #1,0,0,8,26,35
# 2010,2011,1001000,Johnson #1,0,0,0,0,0
# 2010,2011,1101000,Laramie #1,0,0,0,0,0
# 2010,2011,1102000,Laramie #2,0,0,0,0,0
# 2010,2011,1201000,Lincoln #1,0,0,0,3,3
# 2010,2011,1202000,Lincoln #2,0,0,0,0,0
# 2010,2011,1301000,Natrona #1,0,0,73,69,241
# 2010,2011,1401000,Niobrara #1,0,0,0,0,0
# 2010,2011,1501000,Park #1,1,1,151,53,224
# 2010,2011,1506000,Park #6,0,0,2,40,42
# 2010,2011,1516000,Park #16,0,0,17,10,27
# 2010,2011,1601000,Platte #1,0,0,0,0,0
# 2010,2011,1602000,Platte #2,0,0,0,0,0
# 2010,2011,1701000,Sheridan #1,0,0,0,0,0
# 2010,2011,1702000,Sheridan #2,0,0,0,0,0
# 2010,2011,1703000,Sheridan #3,0,0,0,4,4
# 2010,2011,1801000,Sublette #1,0,0,0,0,0
# 2010,2011,1809000,Sublette #9,0,0,89,27,116
# 2010,2011,1901000,Sweetwater #1,0,0,365,285,651
# 2010,2011,1902000,Sweetwater #2,0,0,64,160,224
# 2010,2011,2001000,Teton #1,0,0,0,0,0
# 2010,2011,2101000,Uinta #1,0,0,86,24,255
# 2010,2011,2104000,Uinta #4,0,0,16,34,51
# 2010,2011,2106000,Uinta #6,0,0,0,0,0
# 2010,2011,2201000,Washakie #1,0,0,12,23,35
# 2010,2011,2202000,Washakie #2,0,0,0,0,0
# 2010,2011,2301000,Weston #1,0,0,0,0,0
# 2010,2011,2307000,Weston #7,0,0,0,0,0
# 2011,2012,101000,Albany #1,0,0,4,66,70
# 2010,2011,201000,Big Horn #1,0,0,12,10,22
# 2010,2011,202000,Big Horn #2,0,0,24,27,51
# 2010,2011,203000,Big Horn #3,0,1,29,13,43
# 2010,2011,204000,Big Horn #4,0,0,21,22,43
# 2010,2011,301000,Campbell #1,0,0,212,55,267
# 2010,2011,401000,Carbon #1,4,1,249,250,504
# 2010,2011,402000,Carbon #2,1,0,32,13,46
# 2010,2011,501000,Converse #1,0,0,358,17,375
# 2010,2011,502000,Converse #2,0,1,47,15,63
# 2010,2011,601000,Crook #1,0,0,37,17,54
# 2010,2011,701000,Fremont #1,6,0,257,134,397
# 2010,2011,702000,Fremont #2,0,1,21,47,69
# 2010,2011,706000,Fremont #6,0,0,6,8,14
# 2010,2011,714000,Fremont #14,0,0,0,16,16
# 2010,2011,721000,Fremont #21,0,0,4,46,50
# 2010,2011,724000,Fremont #24,1,0,86,5,92
# 2010,2011,725000,Fremont #25,0,18,799,416,1233
# 2010,2011,738000,Fremont #38,0,0,6,23,29
# 2010,2011,801000,Goshen #1,0,0,1,76,77
# 2010,2011,901000,Hot Springs #1,2,0,11,28,41
# 2010,2011,1001000,Johnson #1,0,0,12,22,34
# 2010,2011,1101000,Laramie #1,0,46,0,53,99
# 2010,2011,1102000,Laramie #2,0,2,71,11,84
# 2010,2011,1201000,Lincoln #1,0,0,1,8,9
# 2010,2011,1202000,Lincoln #2,0,0,14,31,45
# 2010,2011,1301000,Natrona #1,0,0,1734,789,2523
# 2010,2011,1401000,Niobrara #1,0,0,4,0,4
# 2010,2011,1501000,Park #1,2,0,187,70,259
# 2010,2011,1506000,Park #6,1,0,0,34,35
# 2010,2011,1516000,Park #16,0,0,19,6,25
# 2010,2011,1601000,Platte #1,0,0,61,28,89
# 2010,2011,1602000,Platte #2,0,0,0,10,10
# 2010,2011,1701000,Sheridan #1,0,0,23,12,35
# 2010,2011,1702000,Sheridan #2,0,0,22,114,136
# 2010,2011,1703000,Sheridan #3,0,0,0,0,0
# 2010,2011,1801000,Sublette #1,2,0,52,66,120
# 2010,2011,1809000,Sublette #9,0,0,53,42,95
# 2010,2011,1901000,Sweetwater #1,0,0,323,182,505
# 2010,2011,1902000,Sweetwater #2,2,1,439,147,589
# 2010,2011,2001000,Teton #1,0,0,127,63,190
# 2010,2011,2101000,Uinta #1,0,1,93,73,167
# 2010,2011,2104000,Uinta #4,0,0,22,33,55
# 2010,2011,2106000,Uinta #6,0,0,8,12,20
# 2010,2011,2201000,Washakie #1,1,4,21,33,59
# 2010,2011,2202000,Washakie #2,0,0,0,0,0
# 2010,2011,2301000,Weston #1,0,0,0,1,1
# 2010,2011,2307000,Weston #7,0,0,13,1,14
# 2012,2013,101000,Albany #1,0,0,193,50,243
# 2012,2013,201000,Big Horn #1,0,0,13,5,18
# 2012,2013,202000,Big Horn #2,0,0,3,14,17
# 2012,2013,203000,Big Horn #3,0,0,24,7,31
# 2012,2013,204000,Big Horn #4,0,0,19,15,34
# 2012,2013,301000,Campbell #1,1,0,188,75,264
# 2012,2013,401000,Carbon #1,3,0,346,159,508
# 2012,2013,402000,Carbon #2,0,0,12,6,18
# 2012,2013,501000,Converse #1,1,0,283,25,309
# 2012,2013,502000,Converse #2,0,0,88,47,135
# 2012,2013,601000,Crook #1,0,0,16,4,20
# 2012,2013,701000,Fremont #1,1,1,132,95,229
# 2012,2013,702000,Fremont #2,0,0,20,23,43
# 2012,2013,706000,Fremont #6,1,1,7,22,31
# 2012,2013,714000,Fremont #14,0,0,10,6,16
# 2012,2013,721000,Fremont #21,0,0,1,92,93
# 2012,2013,724000,Fremont #24,0,0,56,0,56
# 2012,2013,725000,Fremont #25,0,5,104,129,238
# 2012,2013,738000,Fremont #38,0,0,73,84,157
# 2012,2013,801000,Goshen #1,0,0,11,56,67
# 2012,2013,901000,Hot Springs #1,5,0,0,0,5
# 2012,2013,1001000,Johnson #1,0,0,39,19,58
# 2012,2013,1101000,Laramie #1,0,20,0,48,68
# 2012,2013,1102000,Laramie #2,0,0,55,7,62
# 2012,2013,1201000,Lincoln #1,0,0,0,6,6
# 2012,2013,1202000,Lincoln #2,1,0,91,19,111
# 2012,2013,1301000,Natrona #1,4,53,1831,884,2772
# 2012,2013,1401000,Niobrara #1,0,0,8,0,8
# 2012,2013,1501000,Park #1,0,0,168,46,214
# 2012,2013,1506000,Park #6,0,0,14,20,34
# 2012,2013,1516000,Park #16,0,0,30,7,37
# 2012,2013,1601000,Platte #1,0,0,54,21,75
# 2012,2013,1602000,Platte #2,0,0,0,4,4
# 2012,2013,1701000,Sheridan #1,0,1,30,6,37
# 2012,2013,1702000,Sheridan #2,0,0,54,94,148
# 2012,2013,1801000,Sublette #1,0,0,49,49,98
# 2012,2013,1809000,Sublette #9,0,0,53,31,84
# 2012,2013,1901000,Sweetwater #1,0,0,251,168,419
# 2012,2013,1902000,Sweetwater #2,2,1,870,157,1030
# 2012,2013,2001000,Teton #1,0,0,100,24,124
# 2012,2013,2101000,Uinta #1,1,0,344,99,444
# 2012,2013,2104000,Uinta #4,0,0,28,28,56
# 2012,2013,2106000,Uinta #6,0,0,4,25,29
# 2012,2013,2201000,Washakie #1,0,1,5,23,29
# 2012,2013,2307000,Weston #7,0,0,22,1,23
# 2013,2014,101000,Albany #1,0,0,166,67,233
# 2013,2014,201000,Big Horn #1,0,0,17,11,28
# 2013,2014,202000,Big Horn #2,0,0,10,17,27
# 2013,2014,203000,Big Horn #3,0,1,26,10,37
# 2013,2014,204000,Big Horn #4,0,0,21,25,46
# 2013,2014,301000,Campbell #1,2,0,197,120,319
# 2013,2014,401000,Carbon #1,0,1,413,212,626
# 2013,2014,402000,Carbon #2,0,0,14,15,29
# 2013,2014,501000,Converse #1,0,0,350,12,362
# 2013,2014,502000,Converse #2,0,0,21,29,50
# 2013,2014,601000,Crook #1,0,0,12,10,22
# 2013,2014,701000,Fremont #1,0,2,94,50,146
# 2013,2014,702000,Fremont #2,0,0,22,5,27
# 2013,2014,706000,Fremont #6,0,1,1,15,17
# 2013,2014,714000,Fremont #14,0,0,1,7,8
# 2013,2014,721000,Fremont #21,0,4,19,65,88
# 2013,2014,724000,Fremont #24,0,0,13,2,15
# 2013,2014,725000,Fremont #25,1,0,735,385,1121
# 2013,2014,738000,Fremont #38,0,0,29,136,165
# 2013,2014,801000,Goshen #1,0,0,34,78,112
# 2013,2014,901000,Hot Springs #1,1,0,0,6,7
# 2013,2014,1001000,Johnson #1,1,0,16,14,31
# 2013,2014,1101000,Laramie #1,0,8,0,71,79
# 2013,2014,1102000,Laramie #2,0,0,63,26,89
# 2013,2014,1201000,Lincoln #1,0,0,0,7,7
# 2013,2014,1202000,Lincoln #2,2,0,76,12,90
# 2013,2014,1301000,Natrona #1,6,13,1988,1075,3082
# 2013,2014,1401000,Niobrara #1,0,0,3,1,4
# 2013,2014,1501000,Park #1,0,0,155,57,212
# 2013,2014,1506000,Park #6,0,0,0,35,35
# 2013,2014,1516000,Park #16,0,0,2,2,4
# 2013,2014,1601000,Platte #1,0,0,25,29,54
# 2013,2014,1602000,Platte #2,0,0,0,15,15
# 2013,2014,1701000,Sheridan #1,0,0,27,21,48
# 2013,2014,1702000,Sheridan #2,0,0,32,75,107
# 2013,2014,1703000,Sheridan #3,0,0,1,0,1
# 2013,2014,1801000,Sublette #1,0,0,64,41,105
# 2013,2014,1809000,Sublette #9,0,0,71,43,114
# 2013,2014,1901000,Sweetwater #1,0,0,165,189,354
# 2013,2014,1902000,Sweetwater #2,1,0,954,200,1155
# 2013,2014,2001000,Teton #1,0,1,122,69,192
# 2013,2014,2101000,Uinta #1,0,0,407,114,521
# 2013,2014,2104000,Uinta #4,0,0,13,19,32
# 2013,2014,2106000,Uinta #6,0,0,5,6,11
# 2013,2014,2201000,Washakie #1,0,0,5,32,37
# 2013,2014,2307000,Weston #7,0,0,9,1,10
# 2014,2015,101000,Albany #1,0,0,157,73,230
# 2014,2015,201000,Big Horn #1,0,0,35,13,48
# 2014,2015,202000,Big Horn #2,0,0,11,8,19
# 2014,2015,203000,Big Horn #3,0,0,41,23,64
# 2014,2015,204000,Big Horn #4,0,0,2,0,2
# 2014,2015,301000,Campbell #1,8,5,311,99,423
# 2014,2015,401000,Carbon #1,0,0,223,38,261
# 2014,2015,402000,Carbon #2,0,0,17,8,25
# 2014,2015,501000,Converse #1,0,0,301,24,325
# 2014,2015,502000,Converse #2,0,0,4,33,37
# 2014,2015,601000,Crook #1,0,0,29,18,47
# 2014,2015,701000,Fremont #1,1,1,154,88,244
# 2014,2015,702000,Fremont #2,0,0,4,3,7
# 2014,2015,706000,Fremont #6,0,0,8,15,23
# 2014,2015,714000,Fremont #14,0,0,0,6,6
# 2014,2015,721000,Fremont #21,0,0,0,43,43
# 2014,2015,724000,Fremont #24,0,0,9,7,16
# 2014,2015,725000,Fremont #25,5,2,625,294,926
# 2014,2015,738000,Fremont #38,0,0,10,125,135
# 2014,2015,801000,Goshen #1,0,0,35,103,138
# 2014,2015,901000,Hot Springs #1,0,0,0,3,3
# 2014,2015,1001000,Johnson #1,0,0,10,10,20
# 2014,2015,1101000,Laramie #1,0,5,0,61,66
# 2014,2015,1102000,Laramie #2,0,0,48,9,57
# 2014,2015,1201000,Lincoln #1,0,0,0,4,4
# 2014,2015,1202000,Lincoln #2,1,0,83,18,102
# 2014,2015,1301000,Natrona #1,4,3,1870,1098,2975
# 2014,2015,1401000,Niobrara #1,0,0,0,2,2
# 2014,2015,1501000,Park #1,0,0,237,76,313
# 2014,2015,1506000,Park #6,1,0,21,27,49
# 2014,2015,1516000,Park #16,0,0,0,2,2
# 2014,2015,1601000,Platte #1,0,0,11,33,44
# 2014,2015,1602000,Platte #2,0,0,5,16,21
# 2014,2015,1701000,Sheridan #1,0,0,9,1,10
# 2014,2015,1702000,Sheridan #2,0,0,468,53,521
# 2014,2015,1801000,Sublette #1,0,0,37,56,93
# 2014,2015,1809000,Sublette #9,0,0,53,26,79
# 2014,2015,1901000,Sweetwater #1,0,0,368,115,483
# 2014,2015,1902000,Sweetwater #2,1,0,532,213,746
# 2014,2015,2001000,Teton #1,0,0,116,65,181
# 2014,2015,2101000,Uinta #1,0,3,244,91,338
# 2014,2015,2104000,Uinta #4,2,0,31,14,47
# 2014,2015,2106000,Uinta #6,0,0,14,5,19
# 2014,2015,2201000,Washakie #1,0,0,4,19,23
# 2014,2015,2202000,Washakie #2,0,0,1,0,1
# 2014,2015,2307000,Weston #7,0,6,26,0,32
# 2015,2016,0101000,Albany #1,0,0,194,162,356
# 2015,2016,0202000,Big Horn #2,0,0,8,34,42
# 2015,2016,0203000,Big Horn #3,0,0,34,17,51
# 2015,2016,0204000,Big Horn #4,0,0,21,6,27
# 2015,2016,0301000,Campbell #1,13,1,236,77,327
# 2015,2016,0401000,Carbon #1,0,0,108,143,251
# 2015,2016,0402000,Carbon #2,0,0,30,5,35
# 2015,2016,0501000,Converse #1,0,0,261,17,278
# 2015,2016,0502000,Converse #2,0,0,16,22,38
# 2015,2016,0601000,Crook #1,0,0,25,7,32
# 2015,2016,0701000,Fremont #1,1,1,105,70,177
# 2015,2016,0702000,Fremont #2,0,0,5,14,19
# 2015,2016,0706000,Fremont #6,0,1,9,25,35
# 2015,2016,0714000,Fremont #14,0,0,1,40,41
# 2015,2016,0721000,Fremont #21,0,0,0,69,69
# 2015,2016,0724000,Fremont #24,0,0,7,11,18
# 2015,2016,0725000,Fremont #25,0,3,465,410,878
# 2015,2016,0738000,Fremont #38,0,1,1,57,59
# 2015,2016,0801000,Goshen #1,0,0,84,151,235
# 2015,2016,1001000,Johnson #1,0,0,21,4,25
# 2015,2016,1101000,Laramie #1,2,6,0,68,76
# 2015,2016,1102000,Laramie #2,0,0,38,9,47
# 2015,2016,1201000,Lincoln #1,0,0,0,1,1
# 2015,2016,1202000,Lincoln #2,0,1,144,1,146
# 2015,2016,1301000,Natrona #1,5,7,1929,948,2889
# 2015,2016,1401000,Niobrara #1,0,0,4,4,8
# 2015,2016,1501000,Park #1,4,0,201,99,304
# 2015,2016,1506000,Park #6,0,0,4,29,33
# 2015,2016,1516000,Park #16,0,0,0,5,5
# 2015,2016,1601000,Platte #1,0,0,69,29,98
# 2015,2016,1602000,Platte #2,0,0,7,27,34
# 2015,2016,1701000,Sheridan #1,1,0,42,18,61
# 2015,2016,1702000,Sheridan #2,0,0,619,69,688
# 2015,2016,1801000,Sublette #1,1,0,34,34,69
# 2015,2016,1809000,Sublette #9,0,0,45,21,66
# 2015,2016,1901000,Sweetwater #1,1,0,404,221,626
# 2015,2016,1902000,Sweetwater #2,0,1,426,209,636
# 2015,2016,2001000,Teton #1,0,0,86,44,130
# 2015,2016,2101000,Uinta #1,0,1,761,86,848
# 2015,2016,2104000,Uinta #4,0,0,36,18,54
# 2015,2016,2201000,Washakie #1,0,0,0,18,18
# 2015,2016,2202000,Washakie #2,0,0,2,1,3
# 2015,2016,2307000,Weston #7,0,0,23,3,26
# 0,0,0,0,0,0,0,0,0
# 2016,2017,101000,Albany #1,0,0,47,39,86
# 2016,2017,201000,Big Horn #1,0,0,2,4,6
# 2016,2017,202000,Big Horn #2,0,0,1,2,3
# 2016,2017,203000,Big Horn #3,0,0,17,7,24
# 2016,2017,204000,Big Horn #4,0,0,4,3,7
# 2016,2017,301000,Campbell #1,7,0,0,6,13
# 2016,2017,401000,Carbon #1,0,0,2,4,6
# 2016,2017,402000,Carbon #2,0,0,4,6,10
# 2016,2017,501000,Converse #1,0,0,56,4,60
# 2016,2017,502000,Converse #2,0,0,4,7,11
# 2016,2017,601000,Crook #1,0,0,0,2,2
# 2016,2017,701000,Fremont #1,1,1,2,14,18
# 2016,2017,702000,Fremont #2,0,0,0,2,2
# 2016,2017,706000,Fremont #6,0,0,0,8,8
# 2016,2017,714000,Fremont #14,0,0,2,2,4
# 2016,2017,721000,Fremont #21,0,1,3,5,9
# 2016,2017,724000,Fremont #24,0,0,3,2,5
# 2016,2017,725000,Fremont #25,0,2,64,124,190
# 2016,2017,738000,Fremont #38,0,0,0,1,1
# 2016,2017,801000,Goshen #1,0,0,19,25,44
# 2016,2017,901000,Hot Springs #1,0,0,0,0,0
# 2016,2017,1001000,Johnson #1,0,0,2,3,5
# 2016,2017,1101000,Laramie #1,3,94,0,167,264
# 2016,2017,1102000,Laramie #2,0,0,16,10,26
# 2016,2017,1201000,Lincoln #1,0,0,0,0,0
# 2016,2017,1202000,Lincoln #2,0,1,8,2,11
# 2016,2017,1301000,Natrona #1,3,43,11,3,60
# 2016,2017,1401000,Niobrara #1,0,0,0,0,0
# 2016,2017,1501000,Park #1,3,0,58,21,82
# 2016,2017,1506000,Park #6,0,0,11,12,23
# 2016,2017,1516000,Park #16,0,0,0,1,1
# 2016,2017,1601000,Platte #1,2,2,9,4,17
# 2016,2017,1602000,Platte #2,0,0,0,1,1
# 2016,2017,1701000,Sheridan #1,0,0,6,1,7
# 2016,2017,1702000,Sheridan #2,0,0,49,18,67
# 2016,2017,1703000,Sheridan #3,0,0,0,0,0
# 2016,2017,1801000,Sublette #1,1,0,21,13,35
# 2016,2017,1809000,Sublette #9,0,0,2,4,6
# 2016,2017,1901000,Sweetwater #1,0,1,80,69,150
# 2016,2017,1902000,Sweetwater #2,2,0,22,36,60
# 2016,2017,2001000,Teton #1,1,0,19,17,37
# 2016,2017,2101000,Uinta #1,1,1,32,20,54
# 2016,2017,2104000,Uinta #4,0,0,6,4,10
# 2016,2017,2106000,Uinta #6,0,0,3,1,4
# 2016,2017,2201000,Washakie #1,0,1,1,17,19
# 2016,2017,2202000,Washakie #2,0,0,0,1,1
# 2016,2017,2301000,Weston #1,0,0,0,0,0
# 2016,2017,2307000,Weston #7,2,0,0,2,4
