# %% [markdown]
# method 2: selenium download and then clean
#
# URL: https://www.ojjdp.gov/ojstatbb/ezapop/asp/comparison_selection.asp?selState=56&col_var=v03
#
# method 1 presented some counties as missing years of data

# %%
import time
from selenium import webdriver
#Step 1: using selenium(web browser automation), go to oojdp page and download all files for each age group & year
#        and download the population by race csvs

#from example(ignore)
# driver = webdriver.Chrome('/usr/local/bin/chromedriver')  # Optional argument, if not specified will search path.
# driver.get('http://www.google.com/xhtml');
# time.sleep(5) # Let the user actually see something!
# search_box = driver.find_element_by_name('q')
# search_box.send_keys('ChromeDriver')
# search_box.submit()
# time.sleep(5) # Let the user actually see something!
# driver.quit()

base_url = 'https://www.ojjdp.gov/ojstatbb/ezapop/asp/comparison_selection.asp?selState=56&col_var=v03'
age_group1_url = 'https://www.ojjdp.gov/ojstatbb/ezapop/asp/comparison_selection.asp?selState=56&col_var=v03&selLowerAge=12&selUpperAge=18'

#year range = idv011-idv0128
#age range = v051-v0521

chrome_options = webdriver.ChromeOptions()
prefs = {"download.default_directory": '/home/scrypy/work/wclc/WyJJD/new-data/ojjdp/population-data/method2-cleaning/data'}
chrome_options.add_experimental_option("prefs", prefs)

driver = webdriver.Chrome(executable_path='/usr/local/bin/chromedriver', chrome_options=chrome_options)
    
#UNCOMMENT below to download data for the two age groups
#get all data for age group 10-17
# for year_id in range(1,29):
#     driver.get(age_group1_url)
#     driver.find_element_by_name('SetAge').click()
#     driver.find_element_by_id('idv01{}'.format(year_id)).click()
#     #time.sleep(2)
#     driver.find_element_by_name('submit').click()

#     driver.find_element_by_css_selector('.col4 > a:nth-child(1)').click()
#     #driver.execute_script("window.history.go(-1)")
# time.sleep(2)
    
        
#get all data for age group 18-20
# for year_id in range(1,29):
#     driver.get(base_url)
#     driver.find_element_by_id('idv01{}'.format(year_id)).click()
#     driver.find_element_by_id('idv0519').click()
#     time.sleep(2)
#     driver.find_element_by_name('submit').click()
#     driver.find_element_by_css_selector('.col4 > a:nth-child(1)').click()
    
# time.sleep(2)
driver.quit()

#organized these files into age_group1 and age_group2 folders in data/

# %%
#now combine raw files into two workable .csvs, age_group1.csv and age_group2.csv
from os import listdir
from os.path import isfile, join
agepath1 = './data/age_group1/'
onlyfiles = [f for f in listdir(agepath1) if isfile(join(agepath1, f))]
print(onlyfiles)

outf = open(join('./data/','age_group1.csv'),'w+')
outf.write('Year,Age Range,County,White,Black,American Indian,Asian,Total\n')
for file in onlyfiles:
    with open(join(agepath1,file),'r') as inf:
        state=0
        for row in inf:
            print(row)
            print('row length={}'.format(len(row)))
            #determine state
            if "Year" in row:
                state=1
                year = row.split('=')[1].strip().strip('"')
            elif "Albany" in row:
                state=2
            elif "Suggested" in row:
                state=3
                
            #statework
            if state==1:
                print('Found year:{}'.format(year))
            elif state==2:
                if len(row)!=1:
                    outf.write('{},{},{}'.format(year,'11-17',row))
outf.close()

agepath2 = './data/age_group2/'
onlyfiles = [f for f in listdir(agepath2) if isfile(join(agepath2, f))]
print(onlyfiles)

outf = open(join('./data/','age_group2.csv'),'w+')
outf.write('Year,Age Range,County,White,Black,American Indian,Asian,Total\n')
for file in onlyfiles:
    with open(join(mypath,file),'r') as inf:
        state=0
        for row in inf:
            print(row)
            print('row length={}'.format(len(row)))
            #determine state
            if "Year" in row:
                state=1
                year = row.split('=')[1].strip().strip('"')
            elif "Albany" in row:
                state=2
            elif "Suggested" in row:
                state=3
                
            #statework
            if state==1:
                print('Found year:{}'.format(year))
            elif state==2:
                if len(row)!=1:
                    outf.write('{},{},{}'.format(year,'18-20',row))
outf.close()

#then hand combined the two files into data/all_groups.csv
# Out:
# ['comparison_display (3).csv', 'comparison_display.csv', 'comparison_display (19).csv', 'comparison_display (25).csv', 'comparison_display (18).csv', 'comparison_display (11).csv', 'comparison_display (6).csv', 'comparison_display (20).csv', 'comparison_display (24).csv', 'comparison_display (27).csv', 'comparison_display (9).csv', 'comparison_display (22).csv', 'comparison_display (8).csv', 'comparison_display (16).csv', 'comparison_display (5).csv', 'comparison_display (21).csv', 'comparison_display (14).csv', 'comparison_display (13).csv', 'comparison_display (7).csv', 'comparison_display (4).csv', 'comparison_display (23).csv', 'comparison_display (26).csv', 'comparison_display (15).csv', 'comparison_display (10).csv', 'comparison_display (12).csv', 'comparison_display (2).csv', 'comparison_display (17).csv', 'comparison_display (1).csv']
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1993"
#
# row length=18
# Found year:1993
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1993
#
#
# row length=1
# Found year:1993
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1993
# "All Counties","55139","451","1629","284","57503",
#
# row length=51
# Found year:1993
# "Albany County","2480","30","42","36","2588",
#
# row length=46
# "Big Horn County","1395","0","9","3","1407",
#
# row length=45
# "Campbell County","4323","6","68","13","4410",
#
# row length=47
# "Carbon County","1991","6","7","10","2014",
#
# row length=44
# "Converse County","1575","3","19","3","1600",
#
# row length=46
# "Crook County","718","0","2","0","720",
#
# row length=40
# "Fremont County","3287","7","1109","6","4409",
#
# row length=47
# "Goshen County","1448","0","15","0","1463",
#
# row length=44
# "Hot Springs County","555","0","19","0","574",
#
# row length=47
# "Johnson County","727","0","10","1","738",
#
# row length=43
# "Laramie County","7976","277","90","107","8450",
#
# row length=49
# "Lincoln County","2109","1","13","0","2123",
#
# row length=45
# "Natrona County","7199","66","65","41","7371",
#
# row length=47
# "Niobrara County","266","0","0","0","266",
#
# row length=43
# "Park County","2791","3","14","11","2819",
#
# row length=43
# "Platte County","1019","0","1","0","1020",
#
# row length=43
# "Sheridan County","2870","4","34","16","2924",
#
# row length=47
# "Sublette County","614","0","0","0","614",
#
# row length=43
# "Sweetwater County","5549","46","58","26","5679",
#
# row length=50
# "Teton County","1173","1","8","4","1186",
#
# row length=42
# "Uinta County","3145","1","29","5","3180",
#
# row length=43
# "Washakie County","1100","0","14","2","1116",
#
# row length=46
# "Weston County","829","0","3","0","832",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1990"
#
# row length=18
# Found year:1990
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1990
#
#
# row length=1
# Found year:1990
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1990
# "All Counties","49813","399","1307","306","51825",
#
# row length=51
# Found year:1990
# "Albany County","2228","18","31","39","2316",
#
# row length=46
# "Big Horn County","1287","0","6","4","1297",
#
# row length=45
# "Campbell County","3838","7","49","13","3907",
#
# row length=47
# "Carbon County","1995","6","6","10","2017",
#
# row length=44
# "Converse County","1443","2","18","4","1467",
#
# row length=46
# "Crook County","656","0","1","0","657",
#
# row length=40
# "Fremont County","3061","6","893","7","3967",
#
# row length=46
# "Goshen County","1380","0","15","0","1395",
#
# row length=44
# "Hot Springs County","545","0","18","0","563",
#
# row length=47
# "Johnson County","669","0","8","1","678",
#
# row length=42
# "Laramie County","6965","256","69","114","7404",
#
# row length=49
# "Lincoln County","1914","1","12","0","1927",
#
# row length=45
# "Natrona County","6472","55","46","41","6614",
#
# row length=47
# "Niobrara County","253","0","0","0","253",
#
# row length=43
# "Park County","2454","3","17","11","2485",
#
# row length=43
# "Platte County","938","0","1","0","939",
#
# row length=41
# "Sheridan County","2571","4","29","21","2625",
#
# row length=47
# "Sublette County","536","0","0","0","536",
#
# row length=43
# "Sweetwater County","5082","39","41","29","5191",
#
# row length=50
# "Teton County","890","1","11","4","906",
#
# row length=41
# "Uinta County","2833","1","23","5","2862",
#
# row length=43
# "Washakie County","1039","0","10","3","1052",
#
# row length=46
# "Weston County","764","0","3","0","767",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2009"
#
# row length=18
# Found year:2009
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2009
#
#
# row length=1
# Found year:2009
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2009
# "All Counties","47467","944","2037","482","50930",
#
# row length=51
# Found year:2009
# "Albany County","2026","52","23","67","2168",
#
# row length=46
# "Big Horn County","1214","11","9","3","1237",
#
# row length=46
# "Campbell County","4498","44","94","23","4659",
#
# row length=48
# "Carbon County","1346","8","30","8","1392",
#
# row length=44
# "Converse County","1358","29","16","3","1406",
#
# row length=47
# "Crook County","640","2","8","0","650",
#
# row length=40
# "Fremont County","2461","20","1202","21","3704",
#
# row length=49
# "Goshen County","1087","16","18","5","1126",
#
# row length=45
# "Hot Springs County","377","6","10","4","397",
#
# row length=47
# "Johnson County","734","6","7","3","750",
#
# row length=42
# "Laramie County","7568","394","160","130","8252",
#
# row length=50
# "Lincoln County","1913","15","31","7","1966",
#
# row length=46
# "Natrona County","6510","158","125","62","6855",
#
# row length=49
# "Niobrara County","214","2","0","2","218",
#
# row length=43
# "Park County","2345","22","33","19","2419",
#
# row length=44
# "Platte County","776","4","7","8","795",
#
# row length=41
# "Sheridan County","2406","25","86","16","2533",
#
# row length=48
# "Sublette County","855","6","18","4","883",
#
# row length=44
# "Sweetwater County","4029","83","67","43","4222",
#
# row length=50
# "Teton County","1411","10","15","30","1466",
#
# row length=45
# "Uinta County","2318","20","37","14","2389",
#
# row length=45
# "Washakie County","780","8","26","10","824",
#
# row length=45
# "Weston County","601","3","15","0","619",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2015"
#
# row length=18
# Found year:2015
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2015
#
#
# row length=1
# Found year:2015
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2015
# "All Counties","48216","1069","2166","591","52042",
#
# row length=52
# Found year:2015
# "Albany County","1938","68","40","63","2109",
#
# row length=46
# "Big Horn County","1211","14","11","11","1247",
#
# row length=48
# "Campbell County","4794","63","104","44","5005",
#
# row length=49
# "Carbon County","1318","25","26","10","1379",
#
# row length=46
# "Converse County","1337","23","20","9","1389",
#
# row length=47
# "Crook County","635","8","13","1","657",
#
# row length=41
# "Fremont County","2398","38","1303","22","3761",
#
# row length=49
# "Goshen County","1084","14","13","9","1120",
#
# row length=45
# "Hot Springs County","388","2","5","3","398",
#
# row length=46
# "Johnson County","674","10","11","0","695",
#
# row length=44
# "Laramie County","7894","360","189","155","8598",
#
# row length=50
# "Lincoln County","1922","20","21","7","1970",
#
# row length=46
# "Natrona County","6791","170","143","81","7185",
#
# row length=49
# "Niobrara County","200","4","0","4","208",
#
# row length=43
# "Park County","2209","23","32","14","2278",
#
# row length=44
# "Platte County","682","7","7","5","701",
#
# row length=41
# "Sheridan County","2428","69","57","13","2567",
#
# row length=48
# "Sublette County","833","11","13","28","885",
#
# row length=46
# "Sweetwater County","4303","83","75","53","4514",
#
# row length=50
# "Teton County","1440","12","21","32","1505",
#
# row length=45
# "Uinta County","2334","26","31","14","2405",
#
# row length=45
# "Washakie County","822","7","22","9","860",
#
# row length=44
# "Weston County","581","12","9","4","606",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2008"
#
# row length=18
# Found year:2008
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2008
#
#
# row length=1
# Found year:2008
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2008
# "All Counties","47445","853","2001","461","50760",
#
# row length=51
# Found year:2008
# "Albany County","1971","46","27","51","2095",
#
# row length=46
# "Big Horn County","1217","11","9","4","1241",
#
# row length=46
# "Campbell County","4348","40","84","28","4500",
#
# row length=48
# "Carbon County","1324","7","26","11","1368",
#
# row length=45
# "Converse County","1337","22","12","2","1373",
#
# row length=47
# "Crook County","665","2","7","0","674",
#
# row length=40
# "Fremont County","2497","17","1188","23","3725",
#
# row length=49
# "Goshen County","1062","11","18","5","1096",
#
# row length=45
# "Hot Springs County","371","6","10","5","392",
#
# row length=47
# "Johnson County","762","6","7","3","778",
#
# row length=42
# "Laramie County","7648","362","153","120","8283",
#
# row length=50
# "Lincoln County","1928","14","27","5","1974",
#
# row length=46
# "Natrona County","6552","133","131","64","6880",
#
# row length=49
# "Niobrara County","229","2","0","2","233",
#
# row length=43
# "Park County","2379","23","31","16","2449",
#
# row length=44
# "Platte County","826","4","7","6","843",
#
# row length=41
# "Sheridan County","2452","26","85","18","2581",
#
# row length=48
# "Sublette County","818","6","19","5","848",
#
# row length=44
# "Sweetwater County","3969","76","76","45","4166",
#
# row length=50
# "Teton County","1451","8","14","23","1496",
#
# row length=44
# "Uinta County","2298","20","33","16","2367",
#
# row length=45
# "Washakie County","767","8","24","9","808",
#
# row length=44
# "Weston County","574","3","13","0","590",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2001"
#
# row length=18
# Found year:2001
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2001
#
#
# row length=1
# Found year:2001
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2001
# "All Counties","52443","599","1883","378","55303",
#
# row length=51
# Found year:2001
# "Albany County","2179","43","44","35","2301",
#
# row length=46
# "Big Horn County","1347","6","19","7","1379",
#
# row length=46
# "Campbell County","4518","10","66","24","4618",
#
# row length=48
# "Carbon County","1548","14","20","16","1598",
#
# row length=46
# "Converse County","1463","9","16","5","1493",
#
# row length=46
# "Crook County","733","0","12","0","745",
#
# row length=41
# "Fremont County","2994","11","1179","14","4198",
#
# row length=49
# "Goshen County","1266","5","20","10","1301",
#
# row length=45
# "Hot Springs County","482","1","16","1","500",
#
# row length=47
# "Johnson County","749","0","5","1","755",
#
# row length=42
# "Laramie County","8097","291","112","109","8609",
#
# row length=50
# "Lincoln County","1981","10","14","5","2010",
#
# row length=46
# "Natrona County","7012","100","134","47","7293",
#
# row length=49
# "Niobrara County","247","0","0","1","248",
#
# row length=43
# "Park County","2754","7","17","20","2798",
#
# row length=43
# "Platte County","1021","5","9","3","1038",
#
# row length=43
# "Sheridan County","2844","13","74","26","2957",
#
# row length=48
# "Sublette County","662","2","4","3","671",
#
# row length=43
# "Sweetwater County","4454","58","56","20","4588",
#
# row length=50
# "Teton County","1556","3","5","11","1575",
#
# row length=43
# "Uinta County","2796","3","40","11","2850",
#
# row length=44
# "Washakie County","995","5","11","8","1019",
#
# row length=45
# "Weston County","745","3","10","1","759",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1996"
#
# row length=18
# Found year:1996
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1996
#
#
# row length=1
# Found year:1996
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1996
# "All Counties","57556","509","1793","308","60166",
#
# row length=51
# Found year:1996
# "Albany County","2565","29","38","40","2672",
#
# row length=46
# "Big Horn County","1507","0","9","3","1519",
#
# row length=45
# "Campbell County","4626","5","76","18","4725",
#
# row length=47
# "Carbon County","1928","9","5","16","1958",
#
# row length=44
# "Converse County","1653","5","19","2","1679",
#
# row length=46
# "Crook County","796","0","5","0","801",
#
# row length=40
# "Fremont County","3436","8","1215","5","4664",
#
# row length=47
# "Goshen County","1433","0","20","0","1453",
#
# row length=44
# "Hot Springs County","571","0","19","0","590",
#
# row length=47
# "Johnson County","789","0","7","1","797",
#
# row length=42
# "Laramie County","8390","297","99","110","8896",
#
# row length=49
# "Lincoln County","2245","3","7","0","2255",
#
# row length=44
# "Natrona County","7515","90","91","43","7739",
#
# row length=47
# "Niobrara County","272","0","0","0","272",
#
# row length=43
# "Park County","3020","6","17","14","3057",
#
# row length=43
# "Platte County","1079","0","1","0","1080",
#
# row length=43
# "Sheridan County","3057","8","50","20","3135",
#
# row length=47
# "Sublette County","686","0","0","0","686",
#
# row length=43
# "Sweetwater County","5442","46","62","23","5573",
#
# row length=50
# "Teton County","1358","1","8","4","1371",
#
# row length=42
# "Uinta County","3197","2","30","6","3235",
#
# row length=43
# "Washakie County","1127","0","10","3","1140",
#
# row length=46
# "Weston County","864","0","5","0","869",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2010"
#
# row length=18
# Found year:2010
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2010
#
#
# row length=1
# Found year:2010
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2010
# "All Counties","47171","898","2011","483","50563",
#
# row length=51
# Found year:2010
# "Albany County","1980","49","26","57","2112",
#
# row length=46
# "Big Horn County","1217","10","10","5","1242",
#
# row length=47
# "Campbell County","4525","48","92","31","4696",
#
# row length=48
# "Carbon County","1309","7","27","10","1353",
#
# row length=45
# "Converse County","1338","25","10","1","1374",
#
# row length=47
# "Crook County","634","6","8","0","648",
#
# row length=40
# "Fremont County","2459","30","1204","19","3712",
#
# row length=49
# "Goshen County","1114","15","20","5","1154",
#
# row length=45
# "Hot Springs County","375","8","10","5","398",
#
# row length=47
# "Johnson County","713","7","7","3","730",
#
# row length=42
# "Laramie County","7596","348","151","132","8227",
#
# row length=50
# "Lincoln County","1912","18","29","9","1968",
#
# row length=46
# "Natrona County","6355","140","116","64","6675",
#
# row length=49
# "Niobrara County","207","2","0","2","211",
#
# row length=43
# "Park County","2299","24","34","18","2375",
#
# row length=44
# "Platte County","741","8","6","8","763",
#
# row length=41
# "Sheridan County","2378","26","68","14","2486",
#
# row length=48
# "Sublette County","882","9","21","5","917",
#
# row length=44
# "Sweetwater County","3959","73","78","44","4154",
#
# row length=50
# "Teton County","1421","10","18","26","1475",
#
# row length=45
# "Uinta County","2364","24","34","16","2438",
#
# row length=45
# "Washakie County","799","6","29","9","843",
#
# row length=44
# "Weston County","594","5","13","0","612",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2014"
#
# row length=18
# Found year:2014
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2014
#
#
# row length=1
# Found year:2014
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2014
# "All Counties","47762","1067","2129","562","51520",
#
# row length=52
# Found year:2014
# "Albany County","1927","59","32","81","2099",
#
# row length=46
# "Big Horn County","1195","12","12","11","1230",
#
# row length=48
# "Campbell County","4638","57","113","43","4851",
#
# row length=49
# "Carbon County","1344","17","27","14","1402",
#
# row length=46
# "Converse County","1294","17","18","8","1337",
#
# row length=47
# "Crook County","603","7","13","1","624",
#
# row length=41
# "Fremont County","2406","37","1275","23","3741",
#
# row length=49
# "Goshen County","1094","20","16","8","1138",
#
# row length=45
# "Hot Springs County","395","5","5","4","409",
#
# row length=46
# "Johnson County","653","7","12","1","673",
#
# row length=43
# "Laramie County","7696","369","176","133","8374",
#
# row length=50
# "Lincoln County","1920","19","23","11","1973",
#
# row length=47
# "Natrona County","6608","181","140","76","7005",
#
# row length=49
# "Niobrara County","200","4","0","0","204",
#
# row length=43
# "Park County","2247","25","37","20","2329",
#
# row length=44
# "Platte County","741","8","5","3","757",
#
# row length=41
# "Sheridan County","2458","63","51","13","2585",
#
# row length=48
# "Sublette County","871","12","13","20","916",
#
# row length=46
# "Sweetwater County","4304","85","75","40","4504",
#
# row length=50
# "Teton County","1435","14","20","29","1498",
#
# row length=45
# "Uinta County","2334","25","27","14","2400",
#
# row length=45
# "Washakie County","828","8","24","6","866",
#
# row length=44
# "Weston County","571","16","15","3","605",
#
# row length=43
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2017"
#
# row length=18
# Found year:2017
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2017
#
#
# row length=1
# Found year:2017
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2017
# "All Counties","48602","1128","2198","585","52513",
#
# row length=52
# Found year:2017
# "Albany County","2066","96","39","56","2257",
#
# row length=46
# "Big Horn County","1242","11","9","11","1273",
#
# row length=47
# "Campbell County","4615","60","100","38","4813",
#
# row length=49
# "Carbon County","1293","25","22","11","1351",
#
# row length=46
# "Converse County","1318","12","19","9","1358",
#
# row length=47
# "Crook County","640","8","16","2","666",
#
# row length=41
# "Fremont County","2379","35","1348","23","3785",
#
# row length=49
# "Goshen County","1030","11","18","8","1067",
#
# row length=45
# "Hot Springs County","389","2","3","3","397",
#
# row length=46
# "Johnson County","726","12","19","1","758",
#
# row length=44
# "Laramie County","8103","377","167","167","8814",
#
# row length=50
# "Lincoln County","2029","16","29","10","2084",
#
# row length=47
# "Natrona County","6840","163","144","71","7218",
#
# row length=49
# "Niobrara County","148","3","3","0","154",
#
# row length=43
# "Park County","2322","21","35","13","2391",
#
# row length=44
# "Platte County","648","10","5","4","667",
#
# row length=42
# "Sheridan County","2475","89","52","14","2630",
#
# row length=48
# "Sublette County","803","15","11","39","868",
#
# row length=46
# "Sweetwater County","4323","93","82","43","4541",
#
# row length=50
# "Teton County","1532","20","22","32","1606",
#
# row length=45
# "Uinta County","2278","26","30","18","2352",
#
# row length=45
# "Washakie County","843","10","14","8","875",
#
# row length=45
# "Weston County","560","13","11","4","588",
#
# row length=43
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1999"
#
# row length=18
# Found year:1999
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1999
#
#
# row length=1
# Found year:1999
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1999
# "All Counties","54861","543","1873","336","57613",
#
# row length=51
# Found year:1999
# "Albany County","2329","43","44","38","2454",
#
# row length=46
# "Big Horn County","1436","0","13","4","1453",
#
# row length=46
# "Campbell County","4543","5","77","25","4650",
#
# row length=47
# "Carbon County","1736","10","5","28","1779",
#
# row length=45
# "Converse County","1568","10","19","4","1601",
#
# row length=47
# "Crook County","775","0","7","0","782",
#
# row length=40
# "Fremont County","3228","7","1227","10","4472",
#
# row length=48
# "Goshen County","1323","0","25","0","1348",
#
# row length=44
# "Hot Springs County","524","0","22","0","546",
#
# row length=47
# "Johnson County","768","0","6","1","775",
#
# row length=42
# "Laramie County","8113","298","104","107","8622",
#
# row length=50
# "Lincoln County","2113","4","5","0","2122",
#
# row length=44
# "Natrona County","7200","98","111","42","7451",
#
# row length=48
# "Niobrara County","255","0","0","0","255",
#
# row length=43
# "Park County","2934","5","18","14","2971",
#
# row length=43
# "Platte County","1064","0","1","0","1065",
#
# row length=43
# "Sheridan County","2956","10","70","26","3062",
#
# row length=48
# "Sublette County","687","0","0","0","687",
#
# row length=43
# "Sweetwater County","4958","49","69","24","5100",
#
# row length=50
# "Teton County","1481","2","5","3","1491",
#
# row length=42
# "Uinta County","2993","2","33","6","3034",
#
# row length=43
# "Washakie County","1075","0","9","4","1088",
#
# row length=45
# "Weston County","802","0","3","0","805",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2012"
#
# row length=18
# Found year:2012
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2012
#
#
# row length=1
# Found year:2012
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2012
# "All Counties","47288","920","2018","523","50749",
#
# row length=51
# Found year:2012
# "Albany County","1969","54","27","63","2113",
#
# row length=46
# "Big Horn County","1216","16","14","12","1258",
#
# row length=48
# "Campbell County","4635","46","90","33","4804",
#
# row length=48
# "Carbon County","1301","15","32","12","1360",
#
# row length=46
# "Converse County","1321","29","9","6","1365",
#
# row length=46
# "Crook County","604","8","10","0","622",
#
# row length=41
# "Fremont County","2463","30","1201","17","3711",
#
# row length=49
# "Goshen County","1106","14","21","7","1148",
#
# row length=45
# "Hot Springs County","380","5","8","5","398",
#
# row length=46
# "Johnson County","680","6","6","1","693",
#
# row length=42
# "Laramie County","7609","312","150","122","8193",
#
# row length=50
# "Lincoln County","1863","20","22","6","1911",
#
# row length=46
# "Natrona County","6421","160","136","77","6794",
#
# row length=49
# "Niobrara County","203","1","0","1","205",
#
# row length=43
# "Park County","2270","21","37","25","2353",
#
# row length=44
# "Platte County","692","5","10","9","716",
#
# row length=42
# "Sheridan County","2400","31","63","16","2510",
#
# row length=48
# "Sublette County","895","11","17","12","935",
#
# row length=46
# "Sweetwater County","4184","84","79","39","4386",
#
# row length=50
# "Teton County","1395","11","18","32","1456",
#
# row length=45
# "Uinta County","2306","22","28","18","2374",
#
# row length=45
# "Washakie County","810","8","26","9","853",
#
# row length=44
# "Weston County","565","11","14","1","591",
#
# row length=43
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1998"
#
# row length=18
# Found year:1998
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1998
#
#
# row length=1
# Found year:1998
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1998
# "All Counties","56232","517","1782","327","58858",
#
# row length=51
# Found year:1998
# "Albany County","2387","36","37","36","2496",
#
# row length=46
# "Big Horn County","1492","0","12","3","1507",
#
# row length=46
# "Campbell County","4578","6","75","25","4684",
#
# row length=47
# "Carbon County","1803","13","5","22","1843",
#
# row length=45
# "Converse County","1601","7","19","4","1631",
#
# row length=46
# "Crook County","793","0","6","0","799",
#
# row length=40
# "Fremont County","3353","6","1183","10","4552",
#
# row length=48
# "Goshen County","1390","0","22","0","1412",
#
# row length=44
# "Hot Springs County","559","0","18","0","577",
#
# row length=47
# "Johnson County","777","0","6","1","784",
#
# row length=42
# "Laramie County","8260","293","101","110","8764",
#
# row length=50
# "Lincoln County","2130","3","6","0","2139",
#
# row length=44
# "Natrona County","7350","85","100","42","7577",
#
# row length=48
# "Niobrara County","270","0","0","0","270",
#
# row length=43
# "Park County","3032","3","15","16","3066",
#
# row length=43
# "Platte County","1088","0","1","0","1089",
#
# row length=43
# "Sheridan County","3014","8","56","23","3101",
#
# row length=47
# "Sublette County","684","0","0","0","684",
#
# row length=43
# "Sweetwater County","5174","50","62","20","5306",
#
# row length=50
# "Teton County","1443","1","5","4","1453",
#
# row length=42
# "Uinta County","3104","6","41","7","3158",
#
# row length=43
# "Washakie County","1118","0","9","4","1131",
#
# row length=45
# "Weston County","832","0","3","0","835",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2006"
#
# row length=18
# Found year:2006
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2006
#
#
# row length=1
# Found year:2006
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2006
# "All Counties","48022","754","1987","406","51169",
#
# row length=51
# Found year:2006
# "Albany County","1946","46","30","34","2056",
#
# row length=46
# "Big Horn County","1240","11","11","3","1265",
#
# row length=47
# "Campbell County","4269","35","84","24","4412",
#
# row length=48
# "Carbon County","1310","9","28","12","1359",
#
# row length=45
# "Converse County","1382","23","13","4","1422",
#
# row length=47
# "Crook County","648","2","7","0","657",
#
# row length=40
# "Fremont County","2580","15","1251","20","3866",
#
# row length=49
# "Goshen County","1165","11","19","5","1200",
#
# row length=45
# "Hot Springs County","351","5","8","2","366",
#
# row length=46
# "Johnson County","762","6","6","2","776",
#
# row length=42
# "Laramie County","7846","328","128","128","8430",
#
# row length=50
# "Lincoln County","1864","13","22","5","1904",
#
# row length=46
# "Natrona County","6750","107","123","50","7030",
#
# row length=49
# "Niobrara County","207","1","0","2","210",
#
# row length=43
# "Park County","2439","19","24","17","2499",
#
# row length=44
# "Platte County","900","6","4","4","914",
#
# row length=41
# "Sheridan County","2441","20","69","17","2547",
#
# row length=48
# "Sublette County","740","4","14","3","761",
#
# row length=44
# "Sweetwater County","3884","59","68","32","4043",
#
# row length=50
# "Teton County","1555","6","11","22","1594",
#
# row length=44
# "Uinta County","2335","17","37","12","2401",
#
# row length=45
# "Washakie County","810","9","21","8","848",
#
# row length=44
# "Weston County","598","2","9","0","609",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1995"
#
# row length=18
# Found year:1995
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1995
#
#
# row length=1
# Found year:1995
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1995
# "All Counties","57299","489","1727","292","59807",
#
# row length=51
# Found year:1995
# "Albany County","2550","27","44","37","2658",
#
# row length=46
# "Big Horn County","1488","0","8","4","1500",
#
# row length=45
# "Campbell County","4552","5","67","17","4641",
#
# row length=47
# "Carbon County","1985","8","6","15","2014",
#
# row length=44
# "Converse County","1630","4","19","3","1656",
#
# row length=46
# "Crook County","776","0","4","0","780",
#
# row length=40
# "Fremont County","3431","7","1173","6","4617",
#
# row length=47
# "Goshen County","1435","0","16","0","1451",
#
# row length=44
# "Hot Springs County","564","0","19","0","583",
#
# row length=47
# "Johnson County","772","0","8","1","781",
#
# row length=42
# "Laramie County","8302","296","93","102","8793",
#
# row length=49
# "Lincoln County","2228","2","8","0","2238",
#
# row length=44
# "Natrona County","7510","79","88","41","7718",
#
# row length=47
# "Niobrara County","275","0","0","0","275",
#
# row length=43
# "Park County","3001","3","20","11","3035",
#
# row length=43
# "Platte County","1059","0","1","0","1060",
#
# row length=43
# "Sheridan County","3022","7","44","21","3094",
#
# row length=47
# "Sublette County","671","0","0","0","671",
#
# row length=43
# "Sweetwater County","5549","48","61","22","5680",
#
# row length=50
# "Teton County","1303","2","6","3","1314",
#
# row length=42
# "Uinta County","3202","1","28","6","3237",
#
# row length=43
# "Washakie County","1137","0","10","3","1150",
#
# row length=46
# "Weston County","857","0","4","0","861",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2011"
#
# row length=18
# Found year:2011
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2011
#
#
# row length=1
# Found year:2011
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2011
# "All Counties","47100","906","1985","504","50495",
#
# row length=51
# Found year:2011
# "Albany County","1949","52","26","59","2086",
#
# row length=46
# "Big Horn County","1220","12","10","8","1250",
#
# row length=47
# "Campbell County","4541","50","87","34","4712",
#
# row length=48
# "Carbon County","1314","13","28","11","1366",
#
# row length=46
# "Converse County","1291","27","10","4","1332",
#
# row length=47
# "Crook County","625","8","9","1","643",
#
# row length=40
# "Fremont County","2451","27","1189","16","3683",
#
# row length=49
# "Goshen County","1111","16","20","6","1153",
#
# row length=45
# "Hot Springs County","364","8","7","5","384",
#
# row length=46
# "Johnson County","707","9","7","3","726",
#
# row length=42
# "Laramie County","7564","330","142","128","8164",
#
# row length=50
# "Lincoln County","1873","18","24","9","1924",
#
# row length=46
# "Natrona County","6356","146","130","70","6702",
#
# row length=49
# "Niobrara County","199","6","0","1","206",
#
# row length=43
# "Park County","2281","20","38","20","2359",
#
# row length=44
# "Platte County","728","4","6","9","747",
#
# row length=41
# "Sheridan County","2400","30","62","18","2510",
#
# row length=48
# "Sublette County","895","10","19","6","930",
#
# row length=45
# "Sweetwater County","4077","78","79","39","4273",
#
# row length=50
# "Teton County","1423","6","20","32","1481",
#
# row length=44
# "Uinta County","2339","21","33","16","2409",
#
# row length=45
# "Washakie County","815","8","25","8","856",
#
# row length=44
# "Weston County","577","7","14","1","599",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2004"
#
# row length=18
# Found year:2004
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2004
#
#
# row length=1
# Found year:2004
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2004
# "All Counties","49359","668","1972","382","52381",
#
# row length=51
# Found year:2004
# "Albany County","2063","48","34","39","2184",
#
# row length=46
# "Big Horn County","1325","6","17","6","1354",
#
# row length=46
# "Campbell County","4283","22","80","19","4404",
#
# row length=48
# "Carbon County","1343","12","20","13","1388",
#
# row length=46
# "Converse County","1406","12","13","3","1434",
#
# row length=47
# "Crook County","682","0","10","0","692",
#
# row length=41
# "Fremont County","2706","17","1243","17","3983",
#
# row length=49
# "Goshen County","1178","8","21","5","1212",
#
# row length=44
# "Hot Springs County","389","0","16","3","408",
#
# row length=47
# "Johnson County","746","1","5","2","754",
#
# row length=42
# "Laramie County","8017","300","129","115","8561",
#
# row length=50
# "Lincoln County","1919","13","15","7","1954",
#
# row length=46
# "Natrona County","6755","97","120","46","7018",
#
# row length=48
# "Niobrara County","225","1","0","1","227",
#
# row length=43
# "Park County","2578","15","19","17","2629",
#
# row length=44
# "Platte County","954","3","8","3","968",
#
# row length=41
# "Sheridan County","2572","19","74","19","2684",
#
# row length=48
# "Sublette County","683","3","11","3","700",
#
# row length=44
# "Sweetwater County","4027","65","60","29","4181",
#
# row length=50
# "Teton County","1576","6","10","13","1605",
#
# row length=44
# "Uinta County","2404","11","40","13","2468",
#
# row length=45
# "Washakie County","868","5","17","8","898",
#
# row length=44
# "Weston County","660","4","10","1","675",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2003"
#
# row length=18
# Found year:2003
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2003
#
#
# row length=1
# Found year:2003
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2003
# "All Counties","50117","625","1946","365","53053",
#
# row length=51
# Found year:2003
# "Albany County","2026","45","36","36","2143",
#
# row length=46
# "Big Horn County","1327","7","16","9","1359",
#
# row length=46
# "Campbell County","4395","24","73","19","4511",
#
# row length=48
# "Carbon County","1421","15","17","14","1467",
#
# row length=46
# "Converse County","1473","14","14","7","1508",
#
# row length=47
# "Crook County","691","0","11","0","702",
#
# row length=41
# "Fremont County","2804","13","1237","15","4069",
#
# row length=49
# "Goshen County","1226","9","22","10","1267",
#
# row length=45
# "Hot Springs County","441","1","17","1","460",
#
# row length=47
# "Johnson County","744","1","5","1","751",
#
# row length=42
# "Laramie County","7968","278","126","103","8475",
#
# row length=50
# "Lincoln County","1901","15","13","6","1935",
#
# row length=46
# "Natrona County","6814","85","128","46","7073",
#
# row length=48
# "Niobrara County","219","1","0","0","220",
#
# row length=43
# "Park County","2628","12","20","21","2681",
#
# row length=44
# "Platte County","961","4","8","4","977",
#
# row length=41
# "Sheridan County","2608","18","78","16","2720",
#
# row length=48
# "Sublette County","678","3","6","3","690",
#
# row length=43
# "Sweetwater County","4124","55","52","24","4255",
#
# row length=50
# "Teton County","1545","4","6","10","1565",
#
# row length=43
# "Uinta County","2548","12","35","13","2608",
#
# row length=45
# "Washakie County","900","5","16","6","927",
#
# row length=44
# "Weston County","675","4","10","1","690",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1997"
#
# row length=18
# Found year:1997
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1997
#
#
# row length=1
# Found year:1997
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1997
# "All Counties","57305","475","1796","331","59907",
#
# row length=51
# Found year:1997
# "Albany County","2483","33","41","42","2599",
#
# row length=46
# "Big Horn County","1489","0","11","3","1503",
#
# row length=46
# "Campbell County","4609","5","74","21","4709",
#
# row length=47
# "Carbon County","1888","7","5","22","1922",
#
# row length=44
# "Converse County","1653","6","20","4","1683",
#
# row length=46
# "Crook County","797","0","5","0","802",
#
# row length=40
# "Fremont County","3432","6","1205","5","4648",
#
# row length=47
# "Goshen County","1452","0","19","0","1471",
#
# row length=44
# "Hot Springs County","571","0","19","0","590",
#
# row length=47
# "Johnson County","791","0","5","1","797",
#
# row length=42
# "Laramie County","8374","274","108","115","8871",
#
# row length=50
# "Lincoln County","2185","3","5","0","2193",
#
# row length=44
# "Natrona County","7515","78","97","42","7732",
#
# row length=47
# "Niobrara County","270","0","0","0","270",
#
# row length=43
# "Park County","3073","5","19","14","3111",
#
# row length=43
# "Platte County","1095","0","1","0","1096",
#
# row length=43
# "Sheridan County","3055","6","54","23","3138",
#
# row length=47
# "Sublette County","687","0","0","0","687",
#
# row length=43
# "Sweetwater County","5316","45","58","24","5443",
#
# row length=50
# "Teton County","1418","1","6","4","1429",
#
# row length=42
# "Uinta County","3158","6","31","8","3203",
#
# row length=43
# "Washakie County","1141","0","10","3","1154",
#
# row length=46
# "Weston County","853","0","3","0","856",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1994"
#
# row length=18
# Found year:1994
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1994
#
#
# row length=1
# Found year:1994
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1994
# "All Counties","56723","474","1720","284","59201",
#
# row length=51
# Found year:1994
# "Albany County","2537","26","37","37","2637",
#
# row length=46
# "Big Horn County","1447","0","9","4","1460",
#
# row length=45
# "Campbell County","4434","4","72","15","4525",
#
# row length=47
# "Carbon County","2001","8","8","12","2029",
#
# row length=44
# "Converse County","1602","4","20","3","1629",
#
# row length=46
# "Crook County","761","0","4","0","765",
#
# row length=40
# "Fremont County","3376","7","1161","5","4549",
#
# row length=47
# "Goshen County","1458","0","17","0","1475",
#
# row length=44
# "Hot Springs County","580","0","22","0","602",
#
# row length=47
# "Johnson County","762","0","9","1","772",
#
# row length=42
# "Laramie County","8232","282","96","104","8714",
#
# row length=49
# "Lincoln County","2197","3","10","0","2210",
#
# row length=45
# "Natrona County","7443","81","77","38","7639",
#
# row length=47
# "Niobrara County","268","0","0","0","268",
#
# row length=43
# "Park County","2924","3","20","13","2960",
#
# row length=43
# "Platte County","1049","0","1","0","1050",
#
# row length=43
# "Sheridan County","2958","6","44","19","3027",
#
# row length=47
# "Sublette County","663","0","0","0","663",
#
# row length=43
# "Sweetwater County","5585","48","60","22","5715",
#
# row length=50
# "Teton County","1243","1","7","4","1255",
#
# row length=42
# "Uinta County","3216","1","31","5","3253",
#
# row length=43
# "Washakie County","1139","0","11","2","1152",
#
# row length=46
# "Weston County","848","0","4","0","852",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2013"
#
# row length=18
# Found year:2013
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2013
#
#
# row length=1
# Found year:2013
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2013
# "All Counties","47455","1009","2056","535","51055",
#
# row length=52
# Found year:2013
# "Albany County","1903","52","36","79","2070",
#
# row length=46
# "Big Horn County","1193","17","11","10","1231",
#
# row length=48
# "Campbell County","4646","55","95","34","4830",
#
# row length=48
# "Carbon County","1322","15","32","13","1382",
#
# row length=46
# "Converse County","1342","23","21","7","1393",
#
# row length=47
# "Crook County","610","10","8","1","629",
#
# row length=41
# "Fremont County","2435","40","1235","20","3730",
#
# row length=49
# "Goshen County","1092","12","19","10","1133",
#
# row length=46
# "Hot Springs County","378","4","3","5","390",
#
# row length=46
# "Johnson County","663","6","8","1","678",
#
# row length=42
# "Laramie County","7698","344","158","123","8323",
#
# row length=50
# "Lincoln County","1863","20","24","7","1914",
#
# row length=46
# "Natrona County","6610","177","145","70","7002",
#
# row length=49
# "Niobrara County","201","2","0","1","204",
#
# row length=43
# "Park County","2239","27","36","21","2323",
#
# row length=44
# "Platte County","703","7","4","5","719",
#
# row length=41
# "Sheridan County","2362","48","59","15","2484",
#
# row length=48
# "Sublette County","866","7","15","16","904",
#
# row length=45
# "Sweetwater County","4273","93","68","40","4474",
#
# row length=50
# "Teton County","1388","14","15","30","1447",
#
# row length=45
# "Uinta County","2303","24","25","17","2369",
#
# row length=45
# "Washakie County","823","3","25","7","858",
#
# row length=44
# "Weston County","542","9","14","3","568",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2016"
#
# row length=18
# Found year:2016
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2016
#
#
# row length=1
# Found year:2016
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2016
# "All Counties","48567","1081","2173","601","52422",
#
# row length=52
# Found year:2016
# "Albany County","2018","68","44","62","2192",
#
# row length=46
# "Big Horn County","1242","14","11","9","1276",
#
# row length=47
# "Campbell County","4809","67","102","43","5021",
#
# row length=49
# "Carbon County","1326","19","24","13","1382",
#
# row length=46
# "Converse County","1321","15","19","10","1365",
#
# row length=48
# "Crook County","662","8","14","1","685",
#
# row length=41
# "Fremont County","2389","36","1326","25","3776",
#
# row length=49
# "Goshen County","1046","13","13","8","1080",
#
# row length=45
# "Hot Springs County","395","3","4","2","404",
#
# row length=46
# "Johnson County","694","11","14","2","721",
#
# row length=44
# "Laramie County","7972","367","171","163","8673",
#
# row length=50
# "Lincoln County","1975","23","26","6","2030",
#
# row length=46
# "Natrona County","6851","167","141","78","7237",
#
# row length=49
# "Niobrara County","179","2","3","4","188",
#
# row length=43
# "Park County","2288","21","30","16","2355",
#
# row length=44
# "Platte County","688","9","5","2","704",
#
# row length=41
# "Sheridan County","2407","74","52","15","2548",
#
# row length=48
# "Sublette County","827","13","12","33","885",
#
# row length=46
# "Sweetwater County","4298","94","83","52","4527",
#
# row length=50
# "Teton County","1459","20","22","25","1526",
#
# row length=45
# "Uinta County","2300","22","31","19","2372",
#
# row length=45
# "Washakie County","830","7","15","9","861",
#
# row length=44
# "Weston County","591","8","11","4","614",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2005"
#
# row length=18
# Found year:2005
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2005
#
#
# row length=1
# Found year:2005
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2005
# "All Counties","48473","716","2011","407","51607",
#
# ...
#
# row length=46
# "Hot Springs County","378","4","3","5","390",
#
# row length=46
# "Johnson County","663","6","8","1","678",
#
# row length=42
# "Laramie County","7698","344","158","123","8323",
#
# row length=50
# "Lincoln County","1863","20","24","7","1914",
#
# row length=46
# "Natrona County","6610","177","145","70","7002",
#
# row length=49
# "Niobrara County","201","2","0","1","204",
#
# row length=43
# "Park County","2239","27","36","21","2323",
#
# row length=44
# "Platte County","703","7","4","5","719",
#
# row length=41
# "Sheridan County","2362","48","59","15","2484",
#
# row length=48
# "Sublette County","866","7","15","16","904",
#
# row length=45
# "Sweetwater County","4273","93","68","40","4474",
#
# row length=50
# "Teton County","1388","14","15","30","1447",
#
# row length=45
# "Uinta County","2303","24","25","17","2369",
#
# row length=45
# "Washakie County","823","3","25","7","858",
#
# row length=44
# "Weston County","542","9","14","3","568",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2016"
#
# row length=18
# Found year:2016
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2016
#
#
# row length=1
# Found year:2016
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2016
# "All Counties","48567","1081","2173","601","52422",
#
# row length=52
# Found year:2016
# "Albany County","2018","68","44","62","2192",
#
# row length=46
# "Big Horn County","1242","14","11","9","1276",
#
# row length=47
# "Campbell County","4809","67","102","43","5021",
#
# row length=49
# "Carbon County","1326","19","24","13","1382",
#
# row length=46
# "Converse County","1321","15","19","10","1365",
#
# row length=48
# "Crook County","662","8","14","1","685",
#
# row length=41
# "Fremont County","2389","36","1326","25","3776",
#
# row length=49
# "Goshen County","1046","13","13","8","1080",
#
# row length=45
# "Hot Springs County","395","3","4","2","404",
#
# row length=46
# "Johnson County","694","11","14","2","721",
#
# row length=44
# "Laramie County","7972","367","171","163","8673",
#
# row length=50
# "Lincoln County","1975","23","26","6","2030",
#
# row length=46
# "Natrona County","6851","167","141","78","7237",
#
# row length=49
# "Niobrara County","179","2","3","4","188",
#
# row length=43
# "Park County","2288","21","30","16","2355",
#
# row length=44
# "Platte County","688","9","5","2","704",
#
# row length=41
# "Sheridan County","2407","74","52","15","2548",
#
# row length=48
# "Sublette County","827","13","12","33","885",
#
# row length=46
# "Sweetwater County","4298","94","83","52","4527",
#
# row length=50
# "Teton County","1459","20","22","25","1526",
#
# row length=45
# "Uinta County","2300","22","31","19","2372",
#
# row length=45
# "Washakie County","830","7","15","9","861",
#
# row length=44
# "Weston County","591","8","11","4","614",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2005"
#
# row length=18
# Found year:2005
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2005
#
#
# row length=1
# Found year:2005
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2005
# "All Counties","48473","716","2011","407","51607",
#
# row length=51
# Found year:2005
# "Albany County","1987","48","31","37","2103",
#
# row length=46
# "Big Horn County","1274","8","12","3","1297",
#
# row length=46
# "Campbell County","4227","33","78","23","4361",
#
# row length=48
# "Carbon County","1324","10","23","13","1370",
#
# row length=46
# "Converse County","1359","18","14","5","1396",
#
# row length=47
# "Crook County","670","0","9","0","679",
#
# row length=40
# "Fremont County","2636","18","1265","25","3944",
#
# row length=49
# "Goshen County","1196","9","23","5","1233",
#
# row length=44
# "Hot Springs County","378","3","11","3","395",
#
# row length=47
# "Johnson County","733","5","6","1","745",
#
# row length=42
# "Laramie County","7904","316","130","116","8466",
#
# row length=50
# "Lincoln County","1893","12","18","3","1926",
#
# row length=46
# "Natrona County","6697","104","127","52","6980",
#
# row length=49
# "Niobrara County","216","1","0","2","219",
#
# row length=43
# "Park County","2490","16","21","18","2545",
#
# row length=44
# "Platte County","928","6","8","4","946",
#
# row length=41
# "Sheridan County","2532","20","70","18","2640",
#
# row length=48
# "Sublette County","733","2","11","3","749",
#
# row length=44
# "Sweetwater County","3947","59","68","38","4112",
#
# row length=50
# "Teton County","1544","4","11","18","1577",
#
# row length=44
# "Uinta County","2368","14","40","14","2436",
#
# row length=45
# "Washakie County","816","8","22","6","852",
#
# row length=44
# "Weston County","621","2","13","0","636",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2000"
#
# row length=18
# Found year:2000
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2000
#
#
# row length=1
# Found year:2000
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2000
# "All Counties","53706","595","1843","369","56513",
#
# row length=51
# Found year:2000
# "Albany County","2230","42","41","34","2347",
#
# row length=46
# "Big Horn County","1392","7","19","8","1426",
#
# row length=46
# "Campbell County","4577","11","65","23","4676",
#
# row length=48
# "Carbon County","1649","15","18","20","1702",
#
# row length=46
# "Converse County","1536","8","15","6","1565",
#
# row length=46
# "Crook County","794","0","12","0","806",
#
# row length=41
# "Fremont County","3157","11","1197","12","4377",
#
# row length=49
# "Goshen County","1286","5","19","9","1319",
#
# row length=44
# "Hot Springs County","500","1","17","1","519",
#
# row length=47
# "Johnson County","772","0","6","1","779",
#
# row length=42
# "Laramie County","8033","302","103","108","8546",
#
# row length=50
# "Lincoln County","2081","10","8","5","2104",
#
# row length=45
# "Natrona County","7050","87","108","41","7286",
#
# row length=48
# "Niobrara County","250","0","0","1","251",
#
# row length=43
# "Park County","2894","7","15","23","2939",
#
# row length=43
# "Platte County","1005","7","9","3","1024",
#
# row length=43
# "Sheridan County","2906","11","67","23","3007",
#
# row length=48
# "Sublette County","690","2","2","3","697",
#
# row length=43
# "Sweetwater County","4738","54","60","18","4870",
#
# row length=50
# "Teton County","1501","3","5","9","1518",
#
# row length=42
# "Uinta County","2869","4","38","11","2922",
#
# row length=44
# "Washakie County","1007","5","11","8","1031",
#
# row length=46
# "Weston County","789","3","8","2","802",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2002"
#
# row length=18
# Found year:2002
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2002
#
#
# row length=1
# Found year:2002
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2002
# "All Counties","51435","603","1916","377","54331",
#
# row length=51
# Found year:2002
# "Albany County","2102","45","39","36","2222",
#
# row length=46
# "Big Horn County","1337","6","18","7","1368",
#
# row length=46
# "Campbell County","4513","18","70","25","4626",
#
# row length=48
# "Carbon County","1489","16","19","16","1540",
#
# row length=46
# "Converse County","1468","12","16","7","1503",
#
# row length=47
# "Crook County","723","0","11","0","734",
#
# row length=41
# "Fremont County","2886","12","1217","15","4130",
#
# row length=49
# "Goshen County","1261","5","23","10","1299",
#
# row length=45
# "Hot Springs County","462","1","16","1","480",
#
# row length=47
# "Johnson County","736","0","4","1","741",
# row length=42
# "Laramie County","8017","279","97","103","8496",
#
# row length=49
# "Lincoln County","1950","11","13","7","1981",
#
# row length=46
# "Natrona County","6937","92","129","45","7203",
#
# row length=48
# "Niobrara County","240","1","0","0","241",
#
# row length=43
# "Park County","2686","11","20","20","2737",
#
# row length=44
# "Platte County","1014","5","9","3","1031",
#
# row length=43
# "Sheridan County","2764","13","74","25","2876",
#
# row length=48
# "Sublette County","661","2","4","3","670",
#
# row length=43
# "Sweetwater County","4301","55","61","20","4437",
#
# row length=50
# "Teton County","1555","4","8","11","1578",
#
# row length=43
# "Uinta County","2683","6","43","13","2745",
#
# row length=44
# "Washakie County","941","5","16","7","969",
#
# row length=44
# "Weston County","709","4","9","2","724",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1992"
#
# row length=18
# Found year:1992
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1992
#
#
# row length=1
# Found year:1992
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1992
# "All Counties","53583","477","1508","273","55841",
#
# row length=51
# Found year:1992
# "Albany County","2398","25","37","37","2497",
#
# row length=46
# "Big Horn County","1364","0","6","3","1373",
#
# row length=45
# "Campbell County","4236","7","61","15","4319",
#
# row length=47
# "Carbon County","1994","7","6","7","2014",
#
# row length=43
# "Converse County","1530","3","20","3","1556",
#
# row length=46
# "Crook County","701","0","1","0","702",
#
# row length=40
# "Fremont County","3218","6","1022","7","4253",
#
# row length=47
# "Goshen County","1422","4","14","0","1440",
#
# row length=44
# "Hot Springs County","567","0","20","0","587",
#
# row length=47
# "Johnson County","711","0","9","1","721",
#
# row length=42
# "Laramie County","7645","294","83","100","8122",
#
# row length=49
# "Lincoln County","2049","2","14","0","2065",
#
# row length=45
# "Natrona County","6970","73","62","41","7146",
#
# row length=47
# "Niobrara County","260","0","0","0","260",
#
# row length=43
# "Park County","2668","4","14","11","2697",
#
# row length=43
# "Platte County","990","0","1","0","991",
#
# row length=41
# "Sheridan County","2762","5","28","15","2810",
#
# row length=47
# "Sublette County","586","0","0","0","586",
#
# row length=43
# "Sweetwater County","5476","44","53","22","5595",
#
# row length=50
# "Teton County","1066","2","9","4","1081",
#
# row length=42
# "Uinta County","3088","1","30","5","3124",
#
# row length=43
# "Washakie County","1065","0","14","2","1081",
#
# row length=46
# "Weston County","817","0","4","0","821",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 2007"
#
# row length=18
# Found year:2007
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:2007
#
#
# row length=1
# Found year:2007
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:2007
# "All Counties","47751","800","1981","429","50961",
#
# row length=51
# Found year:2007
# "Albany County","1914","59","33","44","2050",
#
# row length=46
# "Big Horn County","1232","12","12","2","1258",
#
# row length=47
# "Campbell County","4376","37","83","23","4519",
#
# row length=48
# "Carbon County","1281","9","27","12","1329",
#
# row length=45
# "Converse County","1372","26","18","2","1418",
#
# row length=47
# "Crook County","680","2","7","0","689",
#
# row length=40
# "Fremont County","2546","18","1207","17","3788",
#
# row length=49
# "Goshen County","1139","13","18","5","1175",
#
# row length=45
# "Hot Springs County","359","6","8","4","377",
#
# row length=46
# "Johnson County","768","6","6","3","783",
#
# row length=42
# "Laramie County","7751","321","133","130","8335",
#
# row length=50
# "Lincoln County","1866","15","21","5","1907",
#
# row length=46
# "Natrona County","6682","118","132","56","6988",
#
# row length=49
# "Niobrara County","202","1","0","2","205",
#
# row length=43
# "Park County","2372","21","28","20","2441",
#
# row length=44
# "Platte County","877","5","7","7","896",
#
# row length=41
# "Sheridan County","2409","21","77","15","2522",
#
# row length=48
# "Sublette County","781","6","13","4","804",
#
# row length=44
# "Sweetwater County","3907","66","67","35","4075",
#
# row length=50
# "Teton County","1506","9","14","24","1553",
#
# row length=44
# "Uinta County","2328","18","37","11","2394",
#
# row length=45
# "Washakie County","804","9","20","8","841",
#
# row length=44
# "Weston County","599","2","13","0","614",
#
# row length=42
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
# "Easy Access to Juvenile Populations: County Comparisons"
#
# row length=58
# "Table:    Race by County in Wyoming"
#
# row length=38
#
#
# row length=1
# "Selecting:"
#
# row length=13
# "Year = 1991"
#
# row length=18
# Found year:1991
# "Age = 11, 12, 13, 14, 15, 16, 17"
#
# row length=39
# Found year:1991
#
#
# row length=1
# Found year:1991
# "counts","White","Black","American Indian","Asian","Total",
#
# row length=60
# Found year:1991
# "All Counties","51783","423","1429","295","53930",
#
# row length=51
# Found year:1991
# "Albany County","2314","19","35","37","2405",
#
# row length=46
# "Big Horn County","1324","0","6","4","1334",
#
# row length=45
# "Campbell County","4037","7","57","15","4116",
#
# row length=47
# "Carbon County","2008","7","6","9","2030",
#
# row length=43
# "Converse County","1481","2","19","3","1505",
#
# row length=46
# "Crook County","677","0","1","0","678",
#
# row length=40
# "Fremont County","3168","7","981","7","4163",
#
# row length=46
# "Goshen County","1405","0","13","0","1418",
#
# row length=44
# "Hot Springs County","546","0","18","0","564",
#
# row length=47
# "Johnson County","690","0","9","1","700",
#
# row length=42
# "Laramie County","7277","269","76","107","7729",
#
# row length=49
# "Lincoln County","1995","1","13","0","2009",
#
# row length=45
# "Natrona County","6757","60","54","40","6911",
#
# row length=47
# "Niobrara County","256","0","0","0","256",
#
# row length=43
# "Park County","2548","3","13","12","2576",
#
# row length=43
# "Platte County","974","0","1","0","975",
#
# row length=41
# "Sheridan County","2640","5","32","19","2696",
#
# row length=47
# "Sublette County","562","0","0","0","562",
#
# row length=43
# "Sweetwater County","5309","41","47","29","5426",
#
# row length=50
# "Teton County","989","1","10","4","1004",
#
# row length=42
# "Uinta County","2974","1","25","5","3005",
#
# row length=43
# "Washakie County","1057","0","10","3","1070",
#
# row length=46
# "Weston County","795","0","3","0","798",
#
# row length=41
#
#
# row length=1
# "Suggested Citation: Puzzanchera, C., Sladky, A. and Kang, W. (2018). "
#
# row length=72
# "Easy Access to Juvenile Populations: 1990-2017. Online."
#
# row length=58
# "Available: https://www.ojjdp.gov/ojstatbb/ezapop/"
#
# row length=52
